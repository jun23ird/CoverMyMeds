# %% [markdown]
# # Pharmacy claim approval(model selection)
# Jeeuhn Kim

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score,recall_score, f1_score, roc_auc_score
import warnings
warnings.filterwarnings('ignore')

# %%
#loading data
claim = pd.read_csv('dim_claims.csv')
claim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1335576 entries, 0 to 1335575
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   dim_claim_id             1335576 non-null  int64
#  1   bin                      1335576 non-null  int64
#  2   drug                     1335576 non-null  object
#  3   reject_code              555951 non-null   float64
#  4   pharmacy_claim_approved  1335576 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 50.9+ MB

# %%
# change bin numbers to letters to simplify notation

claim.loc[claim.bin ==  417380, 'bin'] = 'x'
claim.loc[claim.bin ==  417614, 'bin'] = 'y'
claim.loc[claim.bin ==  417740, 'bin'] = 'z'
claim.loc[claim.bin ==  999001, 'bin'] = 'w'

# %%
# one hot encoding of categorical variable 'drug'
for i in pd.get_dummies(claim.drug).columns :
    claim.loc[:,i] = pd.get_dummies(claim.drug).loc[:,i].copy()

# %%
# one hot encoding of categorical variable 'bin'
for i in pd.get_dummies(claim.bin).columns :
    claim.loc[:,i] = pd.get_dummies(claim.bin).loc[:, i].copy()

# %%
# add interaction terms
for i in pd.get_dummies(claim.drug).columns :
    for j in pd.get_dummies(claim.bin) : 
        claim.loc[:,i+str(j)] = pd.get_dummies(claim.drug).loc[:,i].copy() * pd.get_dummies(claim.bin).loc[:,j].copy()

# %%
claim.columns
# Out:
# Index(['dim_claim_id', 'bin', 'drug', 'reject_code', 'pharmacy_claim_approved',
#        'A', 'B', 'C', 'w', 'x', 'y', 'z', 'Aw', 'Ax', 'Ay', 'Az', 'Bw', 'Bx',
#        'By', 'Bz', 'Cw', 'Cx', 'Cy', 'Cz'],
#       dtype='object')

# %%
# make a new dataframe that only involves one hot encoded features
X = claim.iloc[:, 5:12].copy()
# make a new dataframe that only involves target variable
y = claim.iloc[:, 4].copy()
# make a new dataframe that only one hot encoded features and interaction terms
X_inter = claim.iloc[:, 5:].copy()

# %%
# split data into training set and test set with test set size =.2 stratified by the target classes
X_train, X_test, X_inter_train, X_inter_test, y_train, y_test = train_test_split(X.copy(),X_inter.copy(), y.copy(),
                                                                                 shuffle = True,
                                                                                 random_state = 623,
                                                                                 test_size = .2,
                                                                                 stratify = claim.pharmacy_claim_approved)

# %%
n = np.empty(9)
n = np.nan
cv = {'accuracy score': n}
# make a dataframe that stores KPIs
kpis = pd.DataFrame(data=cv, 
                       index=['Base','Log', 'LDA','SVM','DT','RF','ET','Ada','XGB'])
# make a dataframe that stores tuned hyperparameters
paras = pd.DataFrame(data=cv, 
                       index=['Base','Log', 'LDA','SVM','DT','RF','ET','Ada','XGB'])

# %%
# make kfold object
kfold = StratifiedKFold(n_splits = 5,
                        shuffle = True,
                        random_state = 623)

# %% [markdown]
# # Baseline model

# %%
# the baseline model predicts that all pharmacy claims will be approved
acses = np.zeros(5)
pres = np.zeros(5)
tprs = np.zeros(5)
fprs = np.zeros(5)
f1s = np.zeros(5)
aucs = np.zeros(5)
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    
    pred = np.ones((len(y_ho)))
    acses[i] = accuracy_score(y_ho.values, pred)
    conf_mat = confusion_matrix(y_ho, pred)
    pres[i] = precision_score(y_ho, pred)
    tprs[i] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
    fprs[i] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
    f1s[i] = f1_score(y_ho, pred)
    aucs[i] = roc_auc_score(y_ho, pred)
    i = i+1

# %%
# storing KPIs
kpis.loc['Base', 'accuracy_score'] = round(acses.mean(),3)
kpis.loc['Base', 'precision'] = round(pres.mean(),3)
kpis.loc['Base', 'true_positive_rate'] = round(tprs.mean(),3)
kpis.loc['Base', 'false_positive_rate'] = round(fprs.mean(),3)
kpis.loc['Base', 'f1'] = round(f1s.mean(),3)
kpis.loc['Base', 'roc_auc'] = round(aucs.mean(),3)

# %% [markdown]
# # Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
# cross validation for various regularization constants and
# various penalty norms
Cs =[.001, .1, 1, 10, 100]
penalties = ['none', 'l2']

acses = np.zeros((5, len(Cs),len(penalties)))
pres = np.zeros((5, len(Cs),len(penalties)))
tprs = np.zeros((5, len(Cs),len(penalties)))
fprs = np.zeros((5, len(Cs),len(penalties)))
f1s = np.zeros((5, len(Cs),len(penalties)))
aucs = np.zeros((5, len(Cs),len(penalties)))


i=0
for train_index, test_index in kfold.split(X_inter_train, y_train) :
    j=0 
    for C in Cs :
        k=0
        for penalty in penalties :
            X_tt = X_inter_train.iloc[train_index, :].copy()
            X_ho = X_inter_train.iloc[test_index, :].copy()
            y_tt = y_train.iloc[train_index].copy()
            y_ho = y_train.iloc[test_index].copy()
            
            log_reg = LogisticRegression(penalty = penalty, C=C, max_iter = 100)
            log_reg.fit(X_tt.values, y_tt.values)
            pred = log_reg.predict(X_ho.values)
            pred_proba = log_reg.predict_proba(X_ho.values)[:, 1]
            acses[i,j,k] = accuracy_score(y_ho.values, pred)
            conf_mat = confusion_matrix(y_ho, pred)
            pres[i,j,k] = precision_score(y_ho, pred)
            tprs[i,j,k] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
            fprs[i,j,k] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
            f1s[i,j,k] = f1_score(y_ho, pred)
            aucs[i,j,k] = roc_auc_score(y_ho, pred_proba)
            k=k+1
        j=j+1      
    i=i+1

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'accuracy_score'] = round(cv_max,3)
paras.loc['Log', 'accuracy_score'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])





# precision
cv = np.mean(pres, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'precision'] = round(cv_max,3)
paras.loc['Log', 'precision'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])





# true_positive_rate
cv = np.mean(tprs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'true_positive_rate'] = round(cv_max,3)
paras.loc['Log', 'true_positive_rate'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])







# false_positive_rate
cv = np.mean(fprs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'false_positive_rate'] = round(cv_max,3)
paras.loc['Log', 'false_positive_rate'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])








# f1_score
cv = np.mean(f1s, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'f1'] = round(cv_max,3)
paras.loc['Log', 'f1'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])







# roc_auc
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][0]
C_index = np.argwhere(cv == cv_max)[0][1]
kpis.loc['Log', 'roc_auc'] = round(cv_max,3)
paras.loc['Log', 'roc_auc'] = 'penalty='+ penalties[penalty_index] +', C='+ str(Cs[C_index])

# %% [markdown]
# # Linear discriminant analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# cross validation process
acses = np.zeros((5,1))
pres = np.zeros((5,1))
tprs = np.zeros((5,1))
fprs = np.zeros((5,1))
f1s = np.zeros((5,1))
aucs = np.zeros((5,1))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()       
    lda = LinearDiscriminantAnalysis()
    lda.fit(X_tt.values, y_tt.values)
    pred = lda.predict(X_ho.values)
    pred_proba = lda.predict_proba(X_ho.values)[:, 1]
    acses[i,0] = accuracy_score(y_ho.values, pred)
    conf_mat = confusion_matrix(y_ho, pred)
    pres[i] = precision_score(y_ho, pred)
    tprs[i] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
    fprs[i] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
    f1s[i] = f1_score(y_ho, pred)
    aucs = roc_auc_score(y_ho, pred_proba)
    i=i+1

# %%
# store KPIs
kpis.loc['LDA', 'accuracy_score'] = round(acses.mean(),3)
kpis.loc['LDA', 'precision'] = round(pres.mean())
kpis.loc['LDA','true_positive_rate'] = round(tprs.mean(),3)
kpis.loc['LDA', 'false_positive_rate'] = round(fprs.mean(),3)
kpis.loc['LDA', 'f1'] = round(f1s.mean(), 3)
kpis.loc['LDA', 'roc_auc'] = round(aucs.mean(), 3)

# %% [markdown]
# # Support vector machine

# %%
from sklearn.svm import SVC

# %%
# cross validation for various margins in support vector machine
margins = [.1, 1, 10, 100]
acses = np.zeros((5,len(margins)))
pres = np.zeros((5,len(margins)))
tprs = np.zeros((5,len(margins)))
fprs = np.zeros((5,len(margins)))
f1s = np.zeros((5,len(margins)))
aucs = np.zeros((5,len(margins)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for margin in margins : 
        svc = SVC(C = margin, max_iter = 10, probability = True)
        svc.fit(X_tt.values, y_tt.values)
        pred_proba = svc.decision_function(X_ho)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        acses[i,j] = accuracy_score(y_ho.values, 1*(pred_proba >= .5))
        conf_mat = confusion_matrix(y_ho, 1*(pred_proba >= .5))
        pres[i,j] = precision_score(y_ho, 1*(pred_proba >= .5))
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, 1*(pred_proba >= .5))
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'accuracy_score'] = round(max_cv,3)
paras.loc['SVM', 'accuracy_score'] = 'margin='+ str(margins[margin_index])





# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'precision'] = round(max_cv,3)
paras.loc['SVM', 'precision'] = 'margin='+ str(margins[margin_index])






# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'true_positive_rate'] = round(max_cv,3)
paras.loc['SVM', 'true_positive_rate'] = 'margin='+ str(margins[margin_index])





# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'false_positive_rate'] = round(max_cv,3)
paras.loc['SVM', 'false_positive_rate'] = 'margin='+ str(margins[margin_index])






# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'f1'] = round(max_cv,3)
paras.loc['SVM', 'f1'] = 'margin='+ str(margins[margin_index])





# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['SVM', 'roc_auc'] = round(max_cv,3)
paras.loc['SVM', 'roc_auc'] = 'margin='+ str(margins[margin_index])

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# cross validation for various max_depths 
max_depths = np.linspace(1, 32, 32, endpoint=True)
acses = np.zeros((5,len(max_depths)))
pres = np.zeros((5,len(max_depths)))
tprs = np.zeros((5,len(max_depths)))
fprs = np.zeros((5,len(max_depths)))
f1s = np.zeros((5,len(max_depths)))
aucs = np.zeros((5,len(max_depths)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for max_depth in max_depths :
        dt = DecisionTreeClassifier(max_depth = max_depth)
        dt.fit(X_tt.values, y_tt.values)
        pred = dt.predict(X_ho.values)
        pred_proba = dt.predict_proba(X_ho.values)[:,1]
        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, pred)
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'accuracy_score'] = round(max_cv,3)
paras.loc['DT', 'accuracy_score'] = 'max_depth='+ str(max_depths[depth_index])





# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'precision'] = round(max_cv,3)
paras.loc['DT', 'precision'] = 'max_depth='+ str(max_depths[depth_index])




# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'true_positive_rate'] = round(max_cv,3)
paras.loc['DT', 'true_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])





# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'false_positive_rate'] = round(max_cv,3)
paras.loc['DT', 'false_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])





# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'f1'] = round(max_cv,3)
paras.loc['DT', 'f1'] = 'max_depth='+ str(max_depths[depth_index])





# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['DT', 'roc_auc'] = round(max_cv,3)
paras.loc['DT', 'roc_auc'] = 'max_depth='+ str(max_depths[depth_index])

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# cross validation for various max_depths
max_depths = [3 ,4, 5, 6]
acses = np.zeros((5,len(max_depths)))
pres = np.zeros((5,len(max_depths)))
tprs = np.zeros((5,len(max_depths)))
fprs = np.zeros((5,len(max_depths)))
f1s = np.zeros((5,len(max_depths)))
aucs = np.zeros((5,len(max_depths)))
drug_score = np.zeros((5,len(max_depths)))
bin_score = np.zeros((5,len(max_depths)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for max_depth in max_depths :
        rf = RandomForestClassifier(n_estimators = 100,
                                    max_depth = max_depth,
                                    random_state = 623)
        rf.fit(X_tt.values,y_tt.values)
        pred = rf.predict(X_ho.values)
        pred_proba = rf.predict_proba(X_ho.values)[:,1]
        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho.values, pred)
        aucs[i,j] = roc_auc_score(y_ho.values, pred_proba)
        drug_score[i,j] = rf.feature_importances_[:3].sum()
        bin_score[i,j] = rf.feature_importances_[3:].sum()
        j=j+1
    i=i+1

# %%
# random forest feature importances
for i in range(len(max_depths)) :
    score_df = pd.DataFrame({'feature':
                             ['drug', 'bin'],
                             'importance_score': 
                             [np.mean(drug_score,axis = 0)[i], np.mean(bin_score,axis=0)[i]]})
    score_df.sort_values('importance_score',ascending=False)
    print('max_depth='+ str(max_depths[i]))
    print(score_df)
# Out:
# max_depth=3
#   feature  importance_score
# 0    drug          0.237752
# 1     bin          0.762248
# max_depth=4
#   feature  importance_score
# 0    drug          0.259754
# 1     bin          0.740246
# max_depth=5
#   feature  importance_score
# 0    drug          0.275184
# 1     bin          0.724816
# max_depth=6
#   feature  importance_score
# 0    drug          0.275184
# 1     bin          0.724816

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'accuracy_score'] = round(max_cv,3)
paras.loc['RF', 'accuracy_score'] = 'max_depth='+ str(max_depths[depth_index])





# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'precision'] = round(max_cv,3)
paras.loc['RF', 'precision'] = 'max_depth='+ str(max_depths[depth_index])






# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'true_positive_rate'] = round(max_cv,3)
paras.loc['RF', 'true_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])





# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'false_positive_rate'] = round(max_cv,3)
paras.loc['RF', 'false_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])




# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'f1'] = round(max_cv,3)
paras.loc['RF', 'f1'] = 'max_depth='+ str(max_depths[depth_index])





# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['RF', 'roc_auc'] = round(max_cv,3)
paras.loc['RF', 'roc_auc'] = 'max_depth='+ str(max_depths[depth_index])

# %% [markdown]
# # ExtraTrees

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
# cross validation for various max_depths
max_depths = [3, 4, 5, 6]
acses = np.zeros((5,len(max_depths)))
pres = np.zeros((5,len(max_depths)))
tprs = np.zeros((5,len(max_depths)))
fprs = np.zeros((5,len(max_depths)))
f1s = np.zeros((5,len(max_depths)))
aucs = np.zeros((5,len(max_depths)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) :
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for max_depth in max_depths :
        et = ExtraTreesClassifier(n_estimators = 100,
                                  max_depth = max_depth,
                                  random_state = 623)
        et.fit(X_tt.values, y_tt.values)
        pred = et.predict(X_ho.values)
        pred_proba = et.predict_proba(X_ho.values)[:,1]
        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, pred)
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'accuracy_score'] = round(max_cv,3)
paras.loc['ET', 'accuracy_score'] = 'max_depth='+ str(max_depths[depth_index])





# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'precision'] = round(max_cv,3)
paras.loc['ET', 'precision'] = 'max_depth='+ str(max_depths[depth_index])








# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'true_positive_rate'] = round(max_cv,3)
paras.loc['ET', 'true_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])







# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'false_positive_rate'] = round(max_cv,3)
paras.loc['ET', 'false_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])




# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'f1'] = round(max_cv,3)
paras.loc['ET', 'f1'] = 'max_depth='+ str(max_depths[depth_index])





# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['ET', 'roc_auc'] = round(max_cv,3)
paras.loc['ET', 'roc_auc'] = 'max_depth='+ str(max_depths[depth_index])

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
# cross validation for various max_depths
max_depths = [3, 4, 5]
acses = np.zeros((5,len(max_depths)))
pres = np.zeros((5,len(max_depths)))
tprs = np.zeros((5,len(max_depths)))
fprs = np.zeros((5,len(max_depths)))
f1s = np.zeros((5,len(max_depths)))
aucs = np.zeros((5,len(max_depths)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for max_depth in max_depths :
        ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth = max_depth),
                                 n_estimators = 100,
                                 random_state = 623)
        ada.fit(X_tt.values, y_tt.values)
        pred = ada.predict(X_ho.values)
        pred_proba = ada.predict_proba(X_ho.values)[:,1]
        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, pred)
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'accuracy_score'] = round(max_cv,3)
paras.loc['Ada', 'accuracy_score'] = 'max_depth='+ str(max_depths[depth_index]) 




# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'precision'] = round(max_cv,3)
paras.loc['Ada', 'precision'] = 'max_depth='+ str(max_depths[depth_index])




# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'true_positive_rate'] = round(max_cv,3)
paras.loc['Ada', 'true_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])


                                                           


# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'false_positive_rate'] = round(max_cv,3)
paras.loc['Ada', 'false_positive_rate'] = 'max_depth='+ str(max_depths[depth_index])





# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'f1'] = round(max_cv,3)
paras.loc['Ada', 'f1'] = 'max_depth='+ str(max_depths[depth_index]) 




# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
kpis.loc['Ada', 'roc_auc'] = round(max_cv,3)
paras.loc['Ada', 'roc_auc'] = 'max_depth='+ str(max_depths[depth_index])

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
# cross validation for various learning_rates and max_depths
learning_rates = [0.01, 0.1, 1, 10, 100]
max_depths = [3, 4, 5]
acses = np.zeros((5,len(learning_rates), len(max_depths)))
pres = np.zeros((5,len(learning_rates), len(max_depths)))
tprs = np.zeros((5,len(learning_rates), len(max_depths)))
fprs = np.zeros((5,len(learning_rates), len(max_depths)))
f1s = np.zeros((5,len(learning_rates), len(max_depths)))
aucs = np.zeros((5,len(learning_rates), len(max_depths)))
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_train.iloc[train_index, :].copy()
    X_ho = X_train.iloc[test_index, :].copy()
    y_tt = y_train.iloc[train_index].copy()
    y_ho = y_train.iloc[test_index].copy()
    j=0
    for learning_rate in learning_rates :
        k=0
        for max_depth in max_depths :
            xgb = XGBClassifier(learning_rate = learning_rate,
                                    max_depth = max_depth,
                                    use_label_encoder=False,
                                    n_estimators = 100,
                                    random_state = 623,
                                    eval_metric = 'logloss')
            xgb.fit(X_tt.values, y_tt.values,
                    early_stopping_rounds = 3,
                    eval_set = [(X_ho.values, y_ho.values)])
            pred = xgb.predict(X_ho.values)
            pred_proba = xgb.predict_proba(X_ho.values)[:,1]
            acses[i,j,k] = accuracy_score(y_ho.values, pred)
            conf_mat = confusion_matrix(y_ho, pred)
            pres[i,j,k] = precision_score(y_ho, pred)
            tprs[i,j,k] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
            fprs[i,j,k] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
            f1s[i,j,k] = f1_score(y_ho, pred)
            aucs[i,j,k] = roc_auc_score(y_ho, pred_proba)
            k=k+1
        j=j+1
    i=i+1
# Out:
# [0]	validation_0-logloss:0.68708
# [1]	validation_0-logloss:0.68101
# [2]	validation_0-logloss:0.67495
# [3]	validation_0-logloss:0.66900
# [4]	validation_0-logloss:0.66323
# [5]	validation_0-logloss:0.65774
# [6]	validation_0-logloss:0.65231
# [7]	validation_0-logloss:0.64670
# [8]	validation_0-logloss:0.64142
# [9]	validation_0-logloss:0.63613
# [10]	validation_0-logloss:0.63104
# [11]	validation_0-logloss:0.62617
# [12]	validation_0-logloss:0.62120
# [13]	validation_0-logloss:0.61648
# [14]	validation_0-logloss:0.61154
# [15]	validation_0-logloss:0.60697
# [16]	validation_0-logloss:0.60239
# [17]	validation_0-logloss:0.59775
# [18]	validation_0-logloss:0.59340
# [19]	validation_0-logloss:0.58925
# [20]	validation_0-logloss:0.58495
# [21]	validation_0-logloss:0.58071
# [22]	validation_0-logloss:0.57653
# [23]	validation_0-logloss:0.57255
# [24]	validation_0-logloss:0.56854
# [25]	validation_0-logloss:0.56469
# [26]	validation_0-logloss:0.56092
# [27]	validation_0-logloss:0.55689
# [28]	validation_0-logloss:0.55317
# [29]	validation_0-logloss:0.54956
# [30]	validation_0-logloss:0.54596
# [31]	validation_0-logloss:0.54243
# [32]	validation_0-logloss:0.53897
# [33]	validation_0-logloss:0.53570
# [34]	validation_0-logloss:0.53229
# [35]	validation_0-logloss:0.52897
# [36]	validation_0-logloss:0.52577
# [37]	validation_0-logloss:0.52253
# [38]	validation_0-logloss:0.51936
# [39]	validation_0-logloss:0.51621
# [40]	validation_0-logloss:0.51324
# [41]	validation_0-logloss:0.51028
# [42]	validation_0-logloss:0.50724
# [43]	validation_0-logloss:0.50440
# [44]	validation_0-logloss:0.50148
# [45]	validation_0-logloss:0.49872
# [46]	validation_0-logloss:0.49596
# [47]	validation_0-logloss:0.49320
# [48]	validation_0-logloss:0.49057
# [49]	validation_0-logloss:0.48792
# [50]	validation_0-logloss:0.48538
# [51]	validation_0-logloss:0.48273
# [52]	validation_0-logloss:0.48018
# [53]	validation_0-logloss:0.47780
# [54]	validation_0-logloss:0.47531
# [55]	validation_0-logloss:0.47292
# [56]	validation_0-logloss:0.47049
# [57]	validation_0-logloss:0.46823
# [58]	validation_0-logloss:0.46592
# [59]	validation_0-logloss:0.46360
# [60]	validation_0-logloss:0.46142
# [61]	validation_0-logloss:0.45920
# [62]	validation_0-logloss:0.45695
# [63]	validation_0-logloss:0.45492
# [64]	validation_0-logloss:0.45221
# [65]	validation_0-logloss:0.45012
# [66]	validation_0-logloss:0.44753
# [67]	validation_0-logloss:0.44497
# [68]	validation_0-logloss:0.44295
# [69]	validation_0-logloss:0.44041
# [70]	validation_0-logloss:0.43798
# [71]	validation_0-logloss:0.43606
# [72]	validation_0-logloss:0.43371
# [73]	validation_0-logloss:0.43135
# [74]	validation_0-logloss:0.42948
# [75]	validation_0-logloss:0.42719
# [76]	validation_0-logloss:0.42491
# [77]	validation_0-logloss:0.42309
# [78]	validation_0-logloss:0.42091
# [79]	validation_0-logloss:0.41876
# [80]	validation_0-logloss:0.41698
# [81]	validation_0-logloss:0.41496
# [82]	validation_0-logloss:0.41321
# [83]	validation_0-logloss:0.41119
# [84]	validation_0-logloss:0.40906
# [85]	validation_0-logloss:0.40748
# [86]	validation_0-logloss:0.40551
# [87]	validation_0-logloss:0.40351
# [88]	validation_0-logloss:0.40195
# [89]	validation_0-logloss:0.40008
# [90]	validation_0-logloss:0.39819
# [91]	validation_0-logloss:0.39666
# [92]	validation_0-logloss:0.39483
# [93]	validation_0-logloss:0.39302
# [94]	validation_0-logloss:0.39156
# [95]	validation_0-logloss:0.38978
# [96]	validation_0-logloss:0.38838
# [97]	validation_0-logloss:0.38666
# [98]	validation_0-logloss:0.38494
# [99]	validation_0-logloss:0.38361
# [0]	validation_0-logloss:0.68694
# [1]	validation_0-logloss:0.68077
# [2]	validation_0-logloss:0.67463
# [3]	validation_0-logloss:0.66861
# [4]	validation_0-logloss:0.66270
# [5]	validation_0-logloss:0.65713
# [6]	validation_0-logloss:0.65160
# [7]	validation_0-logloss:0.64593
# [8]	validation_0-logloss:0.64051
# [9]	validation_0-logloss:0.63515
# [10]	validation_0-logloss:0.62998
# [11]	validation_0-logloss:0.62502
# [12]	validation_0-logloss:0.61995
# [13]	validation_0-logloss:0.61516
# [14]	validation_0-logloss:0.61013
# [15]	validation_0-logloss:0.60547
# [16]	validation_0-logloss:0.60082
# [17]	validation_0-logloss:0.59605
# [18]	validation_0-logloss:0.59164
# [19]	validation_0-logloss:0.58744
# [20]	validation_0-logloss:0.58305
# [21]	validation_0-logloss:0.57872
# [22]	validation_0-logloss:0.57449
# [23]	validation_0-logloss:0.57044
# [24]	validation_0-logloss:0.56637
# [25]	validation_0-logloss:0.56242
# [26]	validation_0-logloss:0.55858
# [27]	validation_0-logloss:0.55452
# [28]	validation_0-logloss:0.55074
# [29]	validation_0-logloss:0.54708
# [30]	validation_0-logloss:0.54342
# [31]	validation_0-logloss:0.53979
# [32]	validation_0-logloss:0.53630
# [33]	validation_0-logloss:0.53300
# [34]	validation_0-logloss:0.52952
# [35]	validation_0-logloss:0.52612
# [36]	validation_0-logloss:0.52287
# [37]	validation_0-logloss:0.51960
# [38]	validation_0-logloss:0.51638
# [39]	validation_0-logloss:0.51314
# [40]	validation_0-logloss:0.51014
# [41]	validation_0-logloss:0.50714
# [42]	validation_0-logloss:0.50406
# [43]	validation_0-logloss:0.50113
# [44]	validation_0-logloss:0.49822
# [45]	validation_0-logloss:0.49543
# [46]	validation_0-logloss:0.49258
# [47]	validation_0-logloss:0.48980
# [48]	validation_0-logloss:0.48714
# [49]	validation_0-logloss:0.48446
# [50]	validation_0-logloss:0.48184
# [51]	validation_0-logloss:0.47920
# [52]	validation_0-logloss:0.47658
# [53]	validation_0-logloss:0.47418
# [54]	validation_0-logloss:0.47170
# [55]	validation_0-logloss:0.46929
# [56]	validation_0-logloss:0.46681
# [57]	validation_0-logloss:0.46451
# [58]	validation_0-logloss:0.46220
# [59]	validation_0-logloss:0.45983
# [60]	validation_0-logloss:0.45763
# [61]	validation_0-logloss:0.45536
# [62]	validation_0-logloss:0.45309
# [63]	validation_0-logloss:0.45101
# [64]	validation_0-logloss:0.44886
# [65]	validation_0-logloss:0.44674
# [66]	validation_0-logloss:0.44474
# [67]	validation_0-logloss:0.44267
# [68]	validation_0-logloss:0.44068
# [69]	validation_0-logloss:0.43871
# [70]	validation_0-logloss:0.43677
# [71]	validation_0-logloss:0.43487
# [72]	validation_0-logloss:0.43306
# [73]	validation_0-logloss:0.43115
# [74]	validation_0-logloss:0.42926
# [75]	validation_0-logloss:0.42747
# [76]	validation_0-logloss:0.42576
# [77]	validation_0-logloss:0.42399
# [78]	validation_0-logloss:0.42228
# [79]	validation_0-logloss:0.42061
# [80]	validation_0-logloss:0.41889
# [81]	validation_0-logloss:0.41726
# [82]	validation_0-logloss:0.41561
# [83]	validation_0-logloss:0.41403
# [84]	validation_0-logloss:0.41245
# [85]	validation_0-logloss:0.41090
# [86]	validation_0-logloss:0.40934
# [87]	validation_0-logloss:0.40785
# [88]	validation_0-logloss:0.40634
# [89]	validation_0-logloss:0.40490
# [90]	validation_0-logloss:0.40353
# [91]	validation_0-logloss:0.40204
# [92]	validation_0-logloss:0.40061
# [93]	validation_0-logloss:0.39925
# [94]	validation_0-logloss:0.39787
# [95]	validation_0-logloss:0.39650
# [96]	validation_0-logloss:0.39523
# [97]	validation_0-logloss:0.39395
# [98]	validation_0-logloss:0.39267
# [99]	validation_0-logloss:0.39141
# [0]	validation_0-logloss:0.68568
# [1]	validation_0-logloss:0.67820
# [2]	validation_0-logloss:0.67080
# [3]	validation_0-logloss:0.66348
# [4]	validation_0-logloss:0.65640
# [5]	validation_0-logloss:0.64964
# [6]	validation_0-logloss:0.64293
# [7]	validation_0-logloss:0.63607
# [8]	validation_0-logloss:0.62957
# [9]	validation_0-logloss:0.62308
# [10]	validation_0-logloss:0.61681
# [11]	validation_0-logloss:0.61081
# [12]	validation_0-logloss:0.60472
# [13]	validation_0-logloss:0.59887
# [14]	validation_0-logloss:0.59285
# [15]	validation_0-logloss:0.58718
# [16]	validation_0-logloss:0.58157
# [17]	validation_0-logloss:0.57584
# [18]	validation_0-logloss:0.57049
# [19]	validation_0-logloss:0.56534
# [20]	validation_0-logloss:0.56005
# [21]	validation_0-logloss:0.55486
# [22]	validation_0-logloss:0.54975
# [23]	validation_0-logloss:0.54480
# [24]	validation_0-logloss:0.53991
# [25]	validation_0-logloss:0.53509
# [26]	validation_0-logloss:0.53045
# [27]	validation_0-logloss:0.52558
# [28]	validation_0-logloss:0.52099
# [29]	validation_0-logloss:0.51656
# [30]	validation_0-logloss:0.51212
# [31]	validation_0-logloss:0.50773
# [32]	validation_0-logloss:0.50350
# [33]	validation_0-logloss:0.49946
# [34]	validation_0-logloss:0.49526
# [35]	validation_0-logloss:0.49117
# [36]	validation_0-logloss:0.48719
# [37]	validation_0-logloss:0.48326
# [38]	validation_0-logloss:0.47937
# [39]	validation_0-logloss:0.47547
# [40]	validation_0-logloss:0.47178
# [41]	validation_0-logloss:0.46813
# [42]	validation_0-logloss:0.46444
# [43]	validation_0-logloss:0.46086
# [44]	validation_0-logloss:0.45734
# [45]	validation_0-logloss:0.45394
# [46]	validation_0-logloss:0.45051
# [47]	validation_0-logloss:0.44714
# [48]	validation_0-logloss:0.44392
# [49]	validation_0-logloss:0.44064
# [50]	validation_0-logloss:0.43748
# [51]	validation_0-logloss:0.43429
# [52]	validation_0-logloss:0.43110
# [53]	validation_0-logloss:0.42815
# [54]	validation_0-logloss:0.42515
# [55]	validation_0-logloss:0.42220
# [56]	validation_0-logloss:0.41923
# [57]	validation_0-logloss:0.41641
# [58]	validation_0-logloss:0.41358
# [59]	validation_0-logloss:0.41074
# [60]	validation_0-logloss:0.40806
# [61]	validation_0-logloss:0.40528
# [62]	validation_0-logloss:0.40258
# [63]	validation_0-logloss:0.40002
# [64]	validation_0-logloss:0.39738
# [65]	validation_0-logloss:0.39484
# [66]	validation_0-logloss:0.39238
# [67]	validation_0-logloss:0.38987
# [68]	validation_0-logloss:0.38744
# [69]	validation_0-logloss:0.38504
# [70]	validation_0-logloss:0.38267
# [71]	validation_0-logloss:0.38039
# [72]	validation_0-logloss:0.37811
# [73]	validation_0-logloss:0.37585
# [74]	validation_0-logloss:0.37352
# [75]	validation_0-logloss:0.37138
# [76]	validation_0-logloss:0.36924
# [77]	validation_0-logloss:0.36710
# [78]	validation_0-logloss:0.36503
# [79]	validation_0-logloss:0.36298
# [80]	validation_0-logloss:0.36089
# [81]	validation_0-logloss:0.35889
# [82]	validation_0-logloss:0.35687
# [83]	validation_0-logloss:0.35496
# [84]	validation_0-logloss:0.35301
# [24]	validation_0-logloss:0.56836
# [25]	validation_0-logloss:0.56445
# [26]	validation_0-logloss:0.56068
# [27]	validation_0-logloss:0.55668
# [28]	validation_0-logloss:0.55304
# [29]	validation_0-logloss:0.54936
# [30]	validation_0-logloss:0.54573
# [31]	validation_0-logloss:0.54220
# [32]	validation_0-logloss:0.53869
# [33]	validation_0-logloss:0.53548
# [34]	validation_0-logloss:0.53206
# [35]	validation_0-logloss:0.52873
# [36]	validation_0-logloss:0.52546
# [37]	validation_0-logloss:0.52224
# [38]	validation_0-logloss:0.51916
# [39]	validation_0-logloss:0.51594
# [40]	validation_0-logloss:0.51293
# [41]	validation_0-logloss:0.51000
# [42]	validation_0-logloss:0.50706
# [43]	validation_0-logloss:0.50417
# [44]	validation_0-logloss:0.50119
# [45]	validation_0-logloss:0.49841
# [46]	validation_0-logloss:0.49561
# [47]	validation_0-logloss:0.49300
# [48]	validation_0-logloss:0.49032
# [49]	validation_0-logloss:0.48761
# [50]	validation_0-logloss:0.48497
# [51]	validation_0-logloss:0.48240
# [52]	validation_0-logloss:0.47992
# [53]	validation_0-logloss:0.47740
# [54]	validation_0-logloss:0.47500
# [55]	validation_0-logloss:0.47252
# [56]	validation_0-logloss:0.47019
# [57]	validation_0-logloss:0.46779
# [58]	validation_0-logloss:0.46558
# [59]	validation_0-logloss:0.46319
# [60]	validation_0-logloss:0.46095
# [61]	validation_0-logloss:0.45882
# [62]	validation_0-logloss:0.45669
# [63]	validation_0-logloss:0.45458
# [64]	validation_0-logloss:0.45190
# [65]	validation_0-logloss:0.44915
# [66]	validation_0-logloss:0.44712
# [67]	validation_0-logloss:0.44455
# [68]	validation_0-logloss:0.44203
# [69]	validation_0-logloss:0.44011
# [70]	validation_0-logloss:0.43763
# [71]	validation_0-logloss:0.43524
# [72]	validation_0-logloss:0.43329
# [73]	validation_0-logloss:0.43085
# [74]	validation_0-logloss:0.42858
# [75]	validation_0-logloss:0.42685
# [76]	validation_0-logloss:0.42448
# [77]	validation_0-logloss:0.42223
# [78]	validation_0-logloss:0.42055
# [79]	validation_0-logloss:0.41833
# [80]	validation_0-logloss:0.41626
# [81]	validation_0-logloss:0.41451
# [82]	validation_0-logloss:0.41245
# [83]	validation_0-logloss:0.41029
# [84]	validation_0-logloss:0.40873
# [85]	validation_0-logloss:0.40672
# [86]	validation_0-logloss:0.40502
# [87]	validation_0-logloss:0.40316
# [88]	validation_0-logloss:0.40122
# [89]	validation_0-logloss:0.39964
# [90]	validation_0-logloss:0.39772
# [91]	validation_0-logloss:0.39593
# [92]	validation_0-logloss:0.39443
# [93]	validation_0-logloss:0.39262
# [94]	validation_0-logloss:0.39076
# [95]	validation_0-logloss:0.38942
# [96]	validation_0-logloss:0.38757
# [97]	validation_0-logloss:0.38617
# [98]	validation_0-logloss:0.38447
# [99]	validation_0-logloss:0.38281
# [0]	validation_0-logloss:0.68695
# [1]	validation_0-logloss:0.68076
# [2]	validation_0-logloss:0.67463
# [3]	validation_0-logloss:0.66859
# [4]	validation_0-logloss:0.66271
# [5]	validation_0-logloss:0.65710
# [6]	validation_0-logloss:0.65157
# [7]	validation_0-logloss:0.64589
# [8]	validation_0-logloss:0.64047
# [9]	validation_0-logloss:0.63509
# [10]	validation_0-logloss:0.62991
# [11]	validation_0-logloss:0.62495
# [12]	validation_0-logloss:0.61985
# [13]	validation_0-logloss:0.61508
# [14]	validation_0-logloss:0.61006
# [15]	validation_0-logloss:0.60538
# [16]	validation_0-logloss:0.60072
# [17]	validation_0-logloss:0.59617
# [18]	validation_0-logloss:0.59174
# [19]	validation_0-logloss:0.58731
# [20]	validation_0-logloss:0.58299
# [21]	validation_0-logloss:0.57864
# [22]	validation_0-logloss:0.57435
# [23]	validation_0-logloss:0.57029
# [24]	validation_0-logloss:0.56625
# [25]	validation_0-logloss:0.56227
# [26]	validation_0-logloss:0.55846
# [27]	validation_0-logloss:0.55437
# [28]	validation_0-logloss:0.55066
# [29]	validation_0-logloss:0.54691
# [30]	validation_0-logloss:0.54326
# [31]	validation_0-logloss:0.53968
# [32]	validation_0-logloss:0.53611
# [33]	validation_0-logloss:0.53282
# [34]	validation_0-logloss:0.52933
# [35]	validation_0-logloss:0.52596
# [36]	validation_0-logloss:0.52268
# [37]	validation_0-logloss:0.51937
# [38]	validation_0-logloss:0.51624
# [39]	validation_0-logloss:0.51298
# [40]	validation_0-logloss:0.50990
# [41]	validation_0-logloss:0.50693
# [42]	validation_0-logloss:0.50396
# [43]	validation_0-logloss:0.50099
# [44]	validation_0-logloss:0.49798
# [45]	validation_0-logloss:0.49520
# [46]	validation_0-logloss:0.49236
# [47]	validation_0-logloss:0.48970
# [48]	validation_0-logloss:0.48700
# [49]	validation_0-logloss:0.48425
# [50]	validation_0-logloss:0.48157
# [51]	validation_0-logloss:0.47900
# [52]	validation_0-logloss:0.47642
# [53]	validation_0-logloss:0.47389
# [54]	validation_0-logloss:0.47150
# [55]	validation_0-logloss:0.46898
# [56]	validation_0-logloss:0.46664
# [57]	validation_0-logloss:0.46420
# [58]	validation_0-logloss:0.46197
# [59]	validation_0-logloss:0.45952
# [60]	validation_0-logloss:0.45729
# [61]	validation_0-logloss:0.45511
# [62]	validation_0-logloss:0.45295
# [63]	validation_0-logloss:0.45079
# [64]	validation_0-logloss:0.44866
# [65]	validation_0-logloss:0.44644
# [66]	validation_0-logloss:0.44446
# [67]	validation_0-logloss:0.44237
# [68]	validation_0-logloss:0.44038
# [69]	validation_0-logloss:0.43850
# [70]	validation_0-logloss:0.43651
# [71]	validation_0-logloss:0.43467
# [72]	validation_0-logloss:0.43273
# [73]	validation_0-logloss:0.43077
# [74]	validation_0-logloss:0.42893
# [75]	validation_0-logloss:0.42726
# [76]	validation_0-logloss:0.42540
# [77]	validation_0-logloss:0.42365
# [78]	validation_0-logloss:0.42202
# [79]	validation_0-logloss:0.42025
# [80]	validation_0-logloss:0.41867
# [81]	validation_0-logloss:0.41690
# [82]	validation_0-logloss:0.41533
# [83]	validation_0-logloss:0.41367
# [84]	validation_0-logloss:0.41218
# [85]	validation_0-logloss:0.41062
# [86]	validation_0-logloss:0.40896
# [87]	validation_0-logloss:0.40754
# [88]	validation_0-logloss:0.40605
# [89]	validation_0-logloss:0.40452
# [90]	validation_0-logloss:0.40312
# [91]	validation_0-logloss:0.40172
# [92]	validation_0-logloss:0.40029
# [93]	validation_0-logloss:0.39895
# [94]	validation_0-logloss:0.39748
# [95]	validation_0-logloss:0.39618
# [96]	validation_0-logloss:0.39482
# [97]	validation_0-logloss:0.39351
# [98]	validation_0-logloss:0.39223
# [99]	validation_0-logloss:0.39096
# [0]	validation_0-logloss:0.68568
# [1]	validation_0-logloss:0.67818
# [2]	validation_0-logloss:0.67077
# [3]	validation_0-logloss:0.66344
# [4]	validation_0-logloss:0.65635
# [5]	validation_0-logloss:0.64958
# [6]	validation_0-logloss:0.64286
# [7]	validation_0-logloss:0.63602
# [8]	validation_0-logloss:0.62950
# [9]	validation_0-logloss:0.62299
# [10]	validation_0-logloss:0.61672
# [11]	validation_0-logloss:0.61072
# [12]	validation_0-logloss:0.60460
# [13]	validation_0-logloss:0.59875
# [14]	validation_0-logloss:0.59274
# [15]	validation_0-logloss:0.58704
# [16]	validation_0-logloss:0.58143
# [17]	validation_0-logloss:0.57588
# [18]	validation_0-logloss:0.57052
# [19]	validation_0-logloss:0.56518
# [20]	validation_0-logloss:0.55993
# [21]	validation_0-logloss:0.55467
# [22]	validation_0-logloss:0.54955
# [23]	validation_0-logloss:0.54459
# [24]	validation_0-logloss:0.53972
# [25]	validation_0-logloss:0.53489
# [26]	validation_0-logloss:0.53024
# [27]	validation_0-logloss:0.52537
# [28]	validation_0-logloss:0.52082
# [29]	validation_0-logloss:0.51632
# [30]	validation_0-logloss:0.51188
# [31]	validation_0-logloss:0.50754
# [32]	validation_0-logloss:0.50325
# [33]	validation_0-logloss:0.49920
# [34]	validation_0-logloss:0.49500
# [35]	validation_0-logloss:0.49093
# [36]	validation_0-logloss:0.48692
# [37]	validation_0-logloss:0.48296
# [38]	validation_0-logloss:0.47913
# [39]	validation_0-logloss:0.47522
# [40]	validation_0-logloss:0.47148
# [41]	validation_0-logloss:0.46786
# [42]	validation_0-logloss:0.46423
# [43]	validation_0-logloss:0.46063
# [44]	validation_0-logloss:0.45703
# [45]	validation_0-logloss:0.45363
# [46]	validation_0-logloss:0.45019
# [47]	validation_0-logloss:0.44690
# [48]	validation_0-logloss:0.44364
# [49]	validation_0-logloss:0.44032
# [50]	validation_0-logloss:0.43709
# [51]	validation_0-logloss:0.43396
# [52]	validation_0-logloss:0.43079
# [53]	validation_0-logloss:0.42775
# [54]	validation_0-logloss:0.42482
# [55]	validation_0-logloss:0.42178
# [56]	validation_0-logloss:0.41890
# [57]	validation_0-logloss:0.41596
# [58]	validation_0-logloss:0.41321
# [59]	validation_0-logloss:0.41032
# [60]	validation_0-logloss:0.40758
# [61]	validation_0-logloss:0.40489
# [62]	validation_0-logloss:0.40227
# [63]	validation_0-logloss:0.39963
# [64]	validation_0-logloss:0.39704
# [65]	validation_0-logloss:0.39441
# [66]	validation_0-logloss:0.39196
# [67]	validation_0-logloss:0.38943
# [68]	validation_0-logloss:0.38701
# [69]	validation_0-logloss:0.38467
# [70]	validation_0-logloss:0.38224
# [71]	validation_0-logloss:0.38000
# [72]	validation_0-logloss:0.37765
# [73]	validation_0-logloss:0.37530
# [74]	validation_0-logloss:0.37306
# [75]	validation_0-logloss:0.37095
# [76]	validation_0-logloss:0.36875
# [77]	validation_0-logloss:0.36662
# [78]	validation_0-logloss:0.36459
# [79]	validation_0-logloss:0.36247
# [80]	validation_0-logloss:0.36046
# [81]	validation_0-logloss:0.35839
# [82]	validation_0-logloss:0.35641
# [83]	validation_0-logloss:0.35443
# [84]	validation_0-logloss:0.35254
# [85]	validation_0-logloss:0.35064
# [86]	validation_0-logloss:0.34866
# [87]	validation_0-logloss:0.34692
# [88]	validation_0-logloss:0.34504
# [89]	validation_0-logloss:0.34326
# [90]	validation_0-logloss:0.34149
# [91]	validation_0-logloss:0.33978
# [92]	validation_0-logloss:0.33802
# [93]	validation_0-logloss:0.33636
# [94]	validation_0-logloss:0.33465
# [95]	validation_0-logloss:0.33302
# [96]	validation_0-logloss:0.33135
# [97]	validation_0-logloss:0.32978
# [98]	validation_0-logloss:0.32820
# [99]	validation_0-logloss:0.32660
# [0]	validation_0-logloss:0.63374
# [1]	validation_0-logloss:0.58545
# [2]	validation_0-logloss:0.54513
# [3]	validation_0-logloss:0.51151
# [4]	validation_0-logloss:0.48317
# [5]	validation_0-logloss:0.45866
# [6]	validation_0-logloss:0.43782
# [7]	validation_0-logloss:0.41432
# [8]	validation_0-logloss:0.39437
# [9]	validation_0-logloss:0.38010
# [10]	validation_0-logloss:0.36436
# [11]	validation_0-logloss:0.35321
# [12]	validation_0-logloss:0.34071
# [13]	validation_0-logloss:0.32993
# [14]	validation_0-logloss:0.32177
# [15]	validation_0-logloss:0.31313
# [16]	validation_0-logloss:0.30552
# [17]	validation_0-logloss:0.29948
# [18]	validation_0-logloss:0.29329
# [19]	validation_0-logloss:0.28830
# [20]	validation_0-logloss:0.28322
# [21]	validation_0-logloss:0.27874
# [22]	validation_0-logloss:0.27480
# [23]	validation_0-logloss:0.27146
# [24]	validation_0-logloss:0.26775
# [25]	validation_0-logloss:0.26445
# [26]	validation_0-logloss:0.26159
# [27]	validation_0-logloss:0.25884
# [28]	validation_0-logloss:0.25632
# [29]	validation_0-logloss:0.25406
# [30]	validation_0-logloss:0.25209
# [31]	validation_0-logloss:0.25035
# [32]	validation_0-logloss:0.24597
# [33]	validation_0-logloss:0.24218
# [34]	validation_0-logloss:0.23888
# [35]	validation_0-logloss:0.23727
# [36]	validation_0-logloss:0.23440
# [37]	validation_0-logloss:0.23183
# [38]	validation_0-logloss:0.22962
# [39]	validation_0-logloss:0.22764
# [40]	validation_0-logloss:0.22593
# [41]	validation_0-logloss:0.22440
# [42]	validation_0-logloss:0.22370
# [43]	validation_0-logloss:0.22238
# [44]	validation_0-logloss:0.22161
# [45]	validation_0-logloss:0.22050
# [46]	validation_0-logloss:0.21988
# [47]	validation_0-logloss:0.21896
# [48]	validation_0-logloss:0.21846
# [49]	validation_0-logloss:0.21767
# [50]	validation_0-logloss:0.21729
# [51]	validation_0-logloss:0.21691
# [16]	validation_0-logloss:0.25492
# [17]	validation_0-logloss:0.24958
# [18]	validation_0-logloss:0.24488
# [19]	validation_0-logloss:0.24080
# [20]	validation_0-logloss:0.23722
# [21]	validation_0-logloss:0.23408
# [22]	validation_0-logloss:0.23128
# [23]	validation_0-logloss:0.22889
# [24]	validation_0-logloss:0.22674
# [25]	validation_0-logloss:0.22486
# [26]	validation_0-logloss:0.22321
# [27]	validation_0-logloss:0.22169
# [28]	validation_0-logloss:0.22039
# [29]	validation_0-logloss:0.21924
# [30]	validation_0-logloss:0.21821
# [31]	validation_0-logloss:0.21732
# [32]	validation_0-logloss:0.21653
# [33]	validation_0-logloss:0.21580
# [34]	validation_0-logloss:0.21513
# [35]	validation_0-logloss:0.21457
# [36]	validation_0-logloss:0.21410
# [37]	validation_0-logloss:0.21363
# [38]	validation_0-logloss:0.21320
# [39]	validation_0-logloss:0.21285
# [40]	validation_0-logloss:0.21251
# [41]	validation_0-logloss:0.21226
# [42]	validation_0-logloss:0.21198
# [43]	validation_0-logloss:0.21171
# [44]	validation_0-logloss:0.21153
# [45]	validation_0-logloss:0.21134
# [46]	validation_0-logloss:0.21116
# [47]	validation_0-logloss:0.21099
# [48]	validation_0-logloss:0.21087
# [49]	validation_0-logloss:0.21074
# [50]	validation_0-logloss:0.21064
# [51]	validation_0-logloss:0.21050
# [52]	validation_0-logloss:0.21045
# [53]	validation_0-logloss:0.21035
# [54]	validation_0-logloss:0.21025
# [55]	validation_0-logloss:0.21022
# [56]	validation_0-logloss:0.21014
# [57]	validation_0-logloss:0.21008
# [58]	validation_0-logloss:0.21002
# [59]	validation_0-logloss:0.20998
# [60]	validation_0-logloss:0.20995
# [61]	validation_0-logloss:0.20993
# [62]	validation_0-logloss:0.20992
# [63]	validation_0-logloss:0.20985
# [64]	validation_0-logloss:0.20982
# [65]	validation_0-logloss:0.20977
# [66]	validation_0-logloss:0.20975
# [67]	validation_0-logloss:0.20974
# [68]	validation_0-logloss:0.20975
# [69]	validation_0-logloss:0.20974
# [70]	validation_0-logloss:0.20974
# [71]	validation_0-logloss:0.20974
# [72]	validation_0-logloss:0.20971
# [73]	validation_0-logloss:0.20968
# [74]	validation_0-logloss:0.20968
# [75]	validation_0-logloss:0.20969
# [76]	validation_0-logloss:0.20965
# [77]	validation_0-logloss:0.20965
# [78]	validation_0-logloss:0.20964
# [79]	validation_0-logloss:0.20963
# [80]	validation_0-logloss:0.20963
# [81]	validation_0-logloss:0.20960
# [82]	validation_0-logloss:0.20960
# [83]	validation_0-logloss:0.20958
# [84]	validation_0-logloss:0.20957
# [85]	validation_0-logloss:0.20957
# [86]	validation_0-logloss:0.20957
# [87]	validation_0-logloss:0.20957
# [88]	validation_0-logloss:0.20957
# [89]	validation_0-logloss:0.20957
# [0]	validation_0-logloss:0.34672
# [1]	validation_0-logloss:0.25963
# [2]	validation_0-logloss:0.24241
# [3]	validation_0-logloss:0.22421
# [4]	validation_0-logloss:0.21549
# [5]	validation_0-logloss:0.21344
# [6]	validation_0-logloss:0.21202
# [7]	validation_0-logloss:0.21036
# [8]	validation_0-logloss:0.20989
# [11]	validation_0-logloss:0.62620
# [12]	validation_0-logloss:0.62121
# [13]	validation_0-logloss:0.61654
# [14]	validation_0-logloss:0.61161
# [15]	validation_0-logloss:0.60703
# [16]	validation_0-logloss:0.60246
# [17]	validation_0-logloss:0.59778
# [18]	validation_0-logloss:0.59343
# [19]	validation_0-logloss:0.58929
# [20]	validation_0-logloss:0.58498
# [21]	validation_0-logloss:0.58074
# [22]	validation_0-logloss:0.57656
# [23]	validation_0-logloss:0.57258
# [24]	validation_0-logloss:0.56858
# [25]	validation_0-logloss:0.56469
# [26]	validation_0-logloss:0.56092
# [27]	validation_0-logloss:0.55693
# [28]	validation_0-logloss:0.55326
# [29]	validation_0-logloss:0.54964
# [30]	validation_0-logloss:0.54601
# [31]	validation_0-logloss:0.54243
# [32]	validation_0-logloss:0.53898
# [33]	validation_0-logloss:0.53578
# [34]	validation_0-logloss:0.53236
# [35]	validation_0-logloss:0.52900
# [36]	validation_0-logloss:0.52579
# [37]	validation_0-logloss:0.52260
# [38]	validation_0-logloss:0.51944
# [39]	validation_0-logloss:0.51629
# [40]	validation_0-logloss:0.51329
# [41]	validation_0-logloss:0.51033
# [42]	validation_0-logloss:0.50740
# [43]	validation_0-logloss:0.50438
# [44]	validation_0-logloss:0.50155
# [45]	validation_0-logloss:0.49879
# [46]	validation_0-logloss:0.49600
# [47]	validation_0-logloss:0.49324
# [48]	validation_0-logloss:0.49068
# [49]	validation_0-logloss:0.48797
# [50]	validation_0-logloss:0.48540
# [51]	validation_0-logloss:0.48281
# [52]	validation_0-logloss:0.48033
# [53]	validation_0-logloss:0.47783
# [54]	validation_0-logloss:0.47530
# [55]	validation_0-logloss:0.47300
# [56]	validation_0-logloss:0.47051
# [57]	validation_0-logloss:0.46823
# [58]	validation_0-logloss:0.46597
# [59]	validation_0-logloss:0.46363
# [60]	validation_0-logloss:0.46143
# [61]	validation_0-logloss:0.45928
# [62]	validation_0-logloss:0.45710
# [63]	validation_0-logloss:0.45430
# [64]	validation_0-logloss:0.45227
# [65]	validation_0-logloss:0.44960
# [66]	validation_0-logloss:0.44705
# [67]	validation_0-logloss:0.44505
# [68]	validation_0-logloss:0.44249
# [69]	validation_0-logloss:0.43998
# [70]	validation_0-logloss:0.43808
# [71]	validation_0-logloss:0.43567
# [72]	validation_0-logloss:0.43329
# [73]	validation_0-logloss:0.43134
# [74]	validation_0-logloss:0.42899
# [75]	validation_0-logloss:0.42673
# [76]	validation_0-logloss:0.42491
# ...
# [69]	validation_0-logloss:0.43929
# [70]	validation_0-logloss:0.43726
# [71]	validation_0-logloss:0.43549
# [72]	validation_0-logloss:0.43364
# [73]	validation_0-logloss:0.43172
# [74]	validation_0-logloss:0.42977
# [75]	validation_0-logloss:0.42813
# [76]	validation_0-logloss:0.42637
# [77]	validation_0-logloss:0.42452
# [78]	validation_0-logloss:0.42290
# [79]	validation_0-logloss:0.42118
# [80]	validation_0-logloss:0.41956
# [81]	validation_0-logloss:0.41785
# [82]	validation_0-logloss:0.41625
# [83]	validation_0-logloss:0.41460
# [84]	validation_0-logloss:0.41311
# [85]	validation_0-logloss:0.41154
# [86]	validation_0-logloss:0.41002
# [87]	validation_0-logloss:0.40850
# [88]	validation_0-logloss:0.40700
# [89]	validation_0-logloss:0.40554
# [90]	validation_0-logloss:0.40418
# [91]	validation_0-logloss:0.40273
# [92]	validation_0-logloss:0.40124
# [93]	validation_0-logloss:0.39988
# [94]	validation_0-logloss:0.39853
# [95]	validation_0-logloss:0.39723
# [96]	validation_0-logloss:0.39594
# [97]	validation_0-logloss:0.39465
# [98]	validation_0-logloss:0.39339
# [99]	validation_0-logloss:0.39206
# [0]	validation_0-logloss:0.68569
# [1]	validation_0-logloss:0.67821
# [2]	validation_0-logloss:0.67083
# [3]	validation_0-logloss:0.66351
# [4]	validation_0-logloss:0.65645
# [5]	validation_0-logloss:0.64969
# [6]	validation_0-logloss:0.64299
# [7]	validation_0-logloss:0.63614
# [8]	validation_0-logloss:0.62964
# [9]	validation_0-logloss:0.62316
# [10]	validation_0-logloss:0.61690
# [11]	validation_0-logloss:0.61090
# [12]	validation_0-logloss:0.60481
# [13]	validation_0-logloss:0.59894
# [14]	validation_0-logloss:0.59297
# [15]	validation_0-logloss:0.58728
# [16]	validation_0-logloss:0.58167
# [17]	validation_0-logloss:0.57598
# [18]	validation_0-logloss:0.57064
# [19]	validation_0-logloss:0.56546
# [20]	validation_0-logloss:0.56021
# [21]	validation_0-logloss:0.55502
# [22]	validation_0-logloss:0.54991
# [23]	validation_0-logloss:0.54492
# [24]	validation_0-logloss:0.54002
# [25]	validation_0-logloss:0.53527
# [26]	validation_0-logloss:0.53062
# [27]	validation_0-logloss:0.52577
# [28]	validation_0-logloss:0.52121
# [29]	validation_0-logloss:0.51677
# [30]	validation_0-logloss:0.51234
# [31]	validation_0-logloss:0.50796
# [32]	validation_0-logloss:0.50372
# [33]	validation_0-logloss:0.49968
# [34]	validation_0-logloss:0.49550
# [35]	validation_0-logloss:0.49142
# [36]	validation_0-logloss:0.48742
# [37]	validation_0-logloss:0.48352
# [38]	validation_0-logloss:0.47962
# [39]	validation_0-logloss:0.47574
# [40]	validation_0-logloss:0.47207
# [41]	validation_0-logloss:0.46840
# [42]	validation_0-logloss:0.46466
# [43]	validation_0-logloss:0.46112
# [44]	validation_0-logloss:0.45758
# [45]	validation_0-logloss:0.45419
# [46]	validation_0-logloss:0.45076
# [47]	validation_0-logloss:0.44743
# [48]	validation_0-logloss:0.44417
# [49]	validation_0-logloss:0.44097
# [50]	validation_0-logloss:0.43780
# [51]	validation_0-logloss:0.43458
# [52]	validation_0-logloss:0.43150
# [53]	validation_0-logloss:0.42849
# [54]	validation_0-logloss:0.42545
# [55]	validation_0-logloss:0.42253
# [56]	validation_0-logloss:0.41957
# [57]	validation_0-logloss:0.41674
# [58]	validation_0-logloss:0.41390
# [59]	validation_0-logloss:0.41112
# [60]	validation_0-logloss:0.40839
# [61]	validation_0-logloss:0.40562
# [62]	validation_0-logloss:0.40302
# [63]	validation_0-logloss:0.40036
# [64]	validation_0-logloss:0.39779
# [65]	validation_0-logloss:0.39519
# [66]	validation_0-logloss:0.39274
# [67]	validation_0-logloss:0.39023
# [68]	validation_0-logloss:0.38782
# [69]	validation_0-logloss:0.38549
# [70]	validation_0-logloss:0.38305
# [71]	validation_0-logloss:0.38083
# [72]	validation_0-logloss:0.37857
# [73]	validation_0-logloss:0.37625
# [74]	validation_0-logloss:0.37392
# [75]	validation_0-logloss:0.37183
# [76]	validation_0-logloss:0.36969
# [77]	validation_0-logloss:0.36750
# [78]	validation_0-logloss:0.36547
# [79]	validation_0-logloss:0.36339
# [80]	validation_0-logloss:0.36138
# [81]	validation_0-logloss:0.35932
# [82]	validation_0-logloss:0.35735
# [83]	validation_0-logloss:0.35538
# [84]	validation_0-logloss:0.35348
# [85]	validation_0-logloss:0.35163
# [86]	validation_0-logloss:0.34974
# [87]	validation_0-logloss:0.34789
# [88]	validation_0-logloss:0.34607
# [89]	validation_0-logloss:0.34426
# [90]	validation_0-logloss:0.34257
# [91]	validation_0-logloss:0.34081
# [92]	validation_0-logloss:0.33908
# [93]	validation_0-logloss:0.33737
# [94]	validation_0-logloss:0.33571
# [95]	validation_0-logloss:0.33409
# [96]	validation_0-logloss:0.33248
# [97]	validation_0-logloss:0.33093
# [98]	validation_0-logloss:0.32936
# [99]	validation_0-logloss:0.32771
# [0]	validation_0-logloss:0.63391
# [1]	validation_0-logloss:0.58562
# [2]	validation_0-logloss:0.54562
# [3]	validation_0-logloss:0.51197
# [4]	validation_0-logloss:0.48374
# [5]	validation_0-logloss:0.45955
# [6]	validation_0-logloss:0.43879
# [7]	validation_0-logloss:0.41528
# [8]	validation_0-logloss:0.39529
# [9]	validation_0-logloss:0.38111
# [10]	validation_0-logloss:0.36548
# [11]	validation_0-logloss:0.35441
# [12]	validation_0-logloss:0.34192
# [13]	validation_0-logloss:0.33112
# [14]	validation_0-logloss:0.32314
# [15]	validation_0-logloss:0.31443
# [16]	validation_0-logloss:0.30694
# [17]	validation_0-logloss:0.30092
# [18]	validation_0-logloss:0.29474
# [19]	validation_0-logloss:0.28984
# [20]	validation_0-logloss:0.28474
# [21]	validation_0-logloss:0.28026
# [22]	validation_0-logloss:0.27644
# [23]	validation_0-logloss:0.27303
# [24]	validation_0-logloss:0.27006
# [25]	validation_0-logloss:0.26645
# [26]	validation_0-logloss:0.26331
# [27]	validation_0-logloss:0.26050
# [28]	validation_0-logloss:0.25804
# [29]	validation_0-logloss:0.25588
# [30]	validation_0-logloss:0.25392
# [31]	validation_0-logloss:0.25161
# [32]	validation_0-logloss:0.24990
# [33]	validation_0-logloss:0.24838
# [34]	validation_0-logloss:0.24442
# [35]	validation_0-logloss:0.24091
# [36]	validation_0-logloss:0.23976
# [37]	validation_0-logloss:0.23689
# [38]	validation_0-logloss:0.23436
# [39]	validation_0-logloss:0.23203
# [40]	validation_0-logloss:0.23002
# [41]	validation_0-logloss:0.22819
# [42]	validation_0-logloss:0.22661
# [43]	validation_0-logloss:0.22522
# [44]	validation_0-logloss:0.22466
# [45]	validation_0-logloss:0.22345
# [46]	validation_0-logloss:0.22297
# [47]	validation_0-logloss:0.22198
# [48]	validation_0-logloss:0.22156
# [21]	validation_0-logloss:0.23594
# [22]	validation_0-logloss:0.23323
# [23]	validation_0-logloss:0.23082
# [24]	validation_0-logloss:0.22869
# [25]	validation_0-logloss:0.22686
# [26]	validation_0-logloss:0.22523
# [27]	validation_0-logloss:0.22375
# [28]	validation_0-logloss:0.22248
# [29]	validation_0-logloss:0.22140
# [30]	validation_0-logloss:0.22037
# [31]	validation_0-logloss:0.21950
# [32]	validation_0-logloss:0.21870
# [33]	validation_0-logloss:0.21800
# [34]	validation_0-logloss:0.21737
# [35]	validation_0-logloss:0.21680
# [36]	validation_0-logloss:0.21632
# [37]	validation_0-logloss:0.21588
# [38]	validation_0-logloss:0.21547
# [39]	validation_0-logloss:0.21511
# [40]	validation_0-logloss:0.21480
# [41]	validation_0-logloss:0.21456
# [42]	validation_0-logloss:0.21426
# [43]	validation_0-logloss:0.21403
# [44]	validation_0-logloss:0.21383
# [45]	validation_0-logloss:0.21366
# [46]	validation_0-logloss:0.21348
# [47]	validation_0-logloss:0.21331
# [48]	validation_0-logloss:0.21317
# [49]	validation_0-logloss:0.21307
# [50]	validation_0-logloss:0.21295
# [51]	validation_0-logloss:0.21285
# [52]	validation_0-logloss:0.21278
# [53]	validation_0-logloss:0.21268
# [54]	validation_0-logloss:0.21261
# [55]	validation_0-logloss:0.21256
# [56]	validation_0-logloss:0.21249
# [57]	validation_0-logloss:0.21244
# [58]	validation_0-logloss:0.21239
# [59]	validation_0-logloss:0.21232
# [60]	validation_0-logloss:0.21230
# [61]	validation_0-logloss:0.21227
# [62]	validation_0-logloss:0.21225
# [63]	validation_0-logloss:0.21222
# [64]	validation_0-logloss:0.21218
# [65]	validation_0-logloss:0.21215
# [66]	validation_0-logloss:0.21212
# [67]	validation_0-logloss:0.21210
# [68]	validation_0-logloss:0.21210
# [69]	validation_0-logloss:0.21210
# [70]	validation_0-logloss:0.21210
# [0]	validation_0-logloss:0.34839
# [1]	validation_0-logloss:0.26149
# [2]	validation_0-logloss:0.24452
# [3]	validation_0-logloss:0.22629
# [4]	validation_0-logloss:0.21770
# [5]	validation_0-logloss:0.21412
# [6]	validation_0-logloss:0.21323
# [7]	validation_0-logloss:0.21292
# [8]	validation_0-logloss:0.21233
# [9]	validation_0-logloss:0.21217
# [10]	validation_0-logloss:0.21212
# [11]	validation_0-logloss:0.21201
# [12]	validation_0-logloss:0.21200
# [13]	validation_0-logloss:0.21195
# [14]	validation_0-logloss:0.21194
# [15]	validation_0-logloss:0.21194
# [16]	validation_0-logloss:0.21194
# [17]	validation_0-logloss:0.21193
# [18]	validation_0-logloss:0.21193
# [19]	validation_0-logloss:0.21193
# [20]	validation_0-logloss:0.21193
# [0]	validation_0-logloss:0.34295
# [1]	validation_0-logloss:0.31069
# [2]	validation_0-logloss:0.30323
# [3]	validation_0-logloss:0.30071
# [4]	validation_0-logloss:0.29978
# [5]	validation_0-logloss:0.29949
# [6]	validation_0-logloss:0.29936
# [7]	validation_0-logloss:0.29927
# [8]	validation_0-logloss:0.29926
# [9]	validation_0-logloss:0.29926
# [10]	validation_0-logloss:0.29926
# [11]	validation_0-logloss:0.29926
# [12]	validation_0-logloss:0.22248
# [13]	validation_0-logloss:0.21516
# [14]	validation_0-logloss:0.21308
# [15]	validation_0-logloss:0.21235
# [16]	validation_0-logloss:0.21208
# [17]	validation_0-logloss:0.21199
# [18]	validation_0-logloss:0.21195
# [19]	validation_0-logloss:0.21194
# [20]	validation_0-logloss:0.21193
# [21]	validation_0-logloss:0.21193
# [22]	validation_0-logloss:0.21194
# [0]	validation_0-logloss:0.26834
# [1]	validation_0-logloss:0.22716
# [2]	validation_0-logloss:0.21726
# [3]	validation_0-logloss:0.21387
# [4]	validation_0-logloss:0.21263
# [5]	validation_0-logloss:0.21221
# [6]	validation_0-logloss:0.21204
# [7]	validation_0-logloss:0.21195
# [8]	validation_0-logloss:0.21194
# [9]	validation_0-logloss:0.21193
# [10]	validation_0-logloss:0.21194
# [11]	validation_0-logloss:0.21193
# [12]	validation_0-logloss:0.21193
# [13]	validation_0-logloss:0.21193
# [14]	validation_0-logloss:0.21194
# [0]	validation_0-logloss:1.09075
# [1]	validation_0-logloss:21.09252
# [2]	validation_0-logloss:21.09252
# [3]	validation_0-logloss:21.09252
# [0]	validation_0-logloss:1.22489
# [1]	validation_0-logloss:19.16976
# [2]	validation_0-logloss:15.33648
# [0]	validation_0-logloss:1.04150
# [1]	validation_0-logloss:1.04150
# [2]	validation_0-logloss:1.04150
# [0]	validation_0-logloss:3.80305
# [1]	validation_0-logloss:3.80305
# [2]	validation_0-logloss:3.80305
# [3]	validation_0-logloss:3.80305
# [0]	validation_0-logloss:4.52742
# [1]	validation_0-logloss:4.52742
# [2]	validation_0-logloss:4.52742
# [0]	validation_0-logloss:2.40672
# [1]	validation_0-logloss:2.40672
# [2]	validation_0-logloss:2.40672

# %%
# accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'accuracy_score'] = round(max_cv,3)
paras.loc['XGB', 'accuracy_score'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index]) 





# precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'precision'] = round(max_cv,3)
paras.loc['XGB', 'precision'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index])





# true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'true_positive_rate'] = round(max_cv,3)
paras.loc['XGB', 'true_positive_rate'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index])



# false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'false_positive_rate'] = round(max_cv,3)
paras.loc['XGB', 'false_positive_rate'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index])



# f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'f1'] = round(max_cv,3)
paras.loc['XGB', 'f1'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index])



# roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
kpis.loc['XGB', 'roc_auc'] = round(max_cv,3)
paras.loc['XGB', 'roc_auc'] = 'learning_rate = ' + str(learning_rates[rate_index]) + 'max_depth = '+ str(max_depths[depth_index])

# %%
kpis
# Out:
#       accuracy score  accuracy_score  precision  true_positive_rate  \
# Base             NaN           0.584      0.584               1.000
# Log              NaN           0.935      0.900               1.000
# LDA              NaN           0.762      1.000               0.739
# SVM              NaN           0.624      0.665               0.858
# DT               NaN           0.935      0.900               1.000
# RF               NaN           0.935      0.900               1.000
# ET               NaN           0.935      0.900               1.000
# Ada              NaN           0.935      0.900               1.000
# XGB              NaN           0.935      0.900               1.000
#
#       false_positive_rate     f1  roc_auc
# Base                1.000  0.737    0.500
# Log                 0.155  0.948    0.922
# LDA                 0.206  0.784    0.852
# SVM                 0.704  0.717    0.623
# DT                  0.221  0.948    0.922
# RF                  0.155  0.948    0.922
# ET                  0.155  0.948    0.922
# Ada                 0.155  0.948    0.922
# XGB                 0.221  0.948    0.922

# %%
paras
# Out:
#       accuracy score                     accuracy_score  \
# Base             NaN                                NaN
# Log              NaN              penalty=none, C=0.001
# LDA              NaN                                NaN
# SVM              NaN                          margin=10
# DT               NaN                      max_depth=5.0
# RF               NaN                        max_depth=3
# ET               NaN                        max_depth=3
# Ada              NaN                        max_depth=3
# XGB              NaN  learning_rate = 0.01max_depth = 5
#
#                               precision                 true_positive_rate  \
# Base                                NaN                                NaN
# Log               penalty=none, C=0.001              penalty=none, C=0.001
# LDA                                 NaN                                NaN
# SVM                            margin=1                          margin=10
# DT                        max_depth=5.0                      max_depth=5.0
# RF                          max_depth=3                        max_depth=3
# ET                          max_depth=3                        max_depth=3
# Ada                         max_depth=3                        max_depth=3
# XGB   learning_rate = 0.01max_depth = 5  learning_rate = 0.01max_depth = 5
#
#                     false_positive_rate                                 f1  \
# Base                                NaN                                NaN
# Log               penalty=none, C=0.001              penalty=none, C=0.001
# LDA                                 NaN                                NaN
# SVM                           margin=10                          margin=10
# DT                        max_depth=4.0                      max_depth=5.0
# RF                          max_depth=3                        max_depth=3
# ET                          max_depth=3                        max_depth=3
# Ada                         max_depth=3                        max_depth=3
# XGB   learning_rate = 0.01max_depth = 4  learning_rate = 0.01max_depth = 5
#
#                               roc_auc
# Base                              NaN
# Log               penalty=none, C=0.1
# LDA                               NaN
# SVM                         margin=10
# DT                      max_depth=5.0
# RF                        max_depth=5
# ET                        max_depth=4
# Ada                       max_depth=3
# XGB   learning_rate = 10max_depth = 5

# %% [markdown]
# # Test set verification of the selected model(Decision Tree)

# %%
dt = DecisionTreeClassifier(max_depth = 5)
dt.fit(X_train.values, y_train.values)
pred = dt.predict(X_test.values)
pred_proba = dt.predict_proba(X_test.values)[:,1]
acs = accuracy_score(y_test.values, pred)
conf_mat = confusion_matrix(y_test, pred)
pre = precision_score(y_test, pred)
tpr = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
fpr = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
f1 = f1_score(y_test, pred)
auc = roc_auc_score(y_test, pred_proba)

# %%
print('accuracy_score = ' + str(acs))
print('precision = ' + str(pre))
print('true_positive_rate = ' + str(tpr))
print('false_positive_rate = ' + str(fpr))
print('f1 = ' + str(f1))
print('roc_auc = ' + str(auc))
# Out:
# accuracy_score = 0.9352041809550907
# precision = 0.9000883203546668
# true_positive_rate = 1.0
# false_positive_rate = 0.15566008040219081
# f1 = 0.9474173497226256
# roc_auc = 0.9223688747588463
