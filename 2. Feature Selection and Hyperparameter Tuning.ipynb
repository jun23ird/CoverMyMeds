# %% [markdown]
# # Feature Selection and Hyperparameter Tuning

# %% [markdown]
# ### Project Goal  : build a model predicting  `pa_approved` based on the following features<br>
# - `bin`  The BIN of the payer(insurance company) for the claim.
# - `drug`   The drug that was associated with the claim.
# - `reject_code`   If the claim was rejected, what was the associated rejection code. It tells you the reason why the claim has been rejected.
# - `correct_diagnosis`    Flag for information provided by the provider indicating that the patient has the correct diagnosis for the associated drug.
# - `tried_and_failed`    Flag for information provided by the provider indicating that the patient has tried and failed the relevant generic alternatives.
# - `contraindication`    Flag for information provided by the provider indicating that the patient has an associated contraindication for the medication requested.

# %% [markdown]
# ### Summary of what have been done in the previous notebooks
# - We concluded that the feature `reject_code` is redundant and dropped from our model.
# - We noticed that there were some nontrivial interaction between features and added the interaction terms of the pairs(`bin`, `drug`), (`tried_and_faild`,`drug`),(`contraindication`,`drug`).

# %% [markdown]
# ### Summary of this notebook
# We will select features and tune hyperparameters via cross validation on preprocessing data set with respect to each key performance indicator. More precisely,  we will choose features and hyperparameters that optimize `accuracy_score`,`precision`, `true_positive_rate`, `false_positive_rate`, `f1` and `roc_auc` respectively. Note that this feature selection is different from the feature selection that have been done in EDA notebook.<br><br>
#  &emsp; - In EDA we did not take into account the target variable when performing feature selection.<br>
# &emsp; - In this note we perform feature selection using the target variable.<br><br>
# In the end, we will be using `roc_auc` as our key performance indicator but we will also build machine learning models based on other key performance indicators i.e. `accuracy_score`,`precision`, `true_positive_rate`, `false_positive_rate` and `f1`.

# %% [markdown]
# As a result, we will choose logistic regression as our machine learning model.

# %% [markdown]
# ## 0. Load Libraries and Data

# %% [markdown]
# Recall that we split data into three parts 'pre'(`X_pre`,`y_pre`), 'train'(`X_train`, `y_train`) and 'test'(`X_test`, `y_test`).  `X_pre_inter`,`X_train_inter` and`X_test_inter` are `X_pre`,`X_train` and `X_test` with columns encoding interaction terms added.<br>
# - `X_pre(_inter)`,`y_pre(_inter)` will be used for the exploratory data analysis, feature selection and hyperparameter tuning.
# - `X_train`, `y_train` will be used for model selection.
# - `X_test`, `y_test` will be used for model assessment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score,recall_score, f1_score, roc_auc_score, r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
# load data
X_pre = pd.read_csv('data/X_pre',index_col = 0)
X_train = pd.read_csv('data/X_train',index_col = 0)
X_inter_pre = pd.read_csv('data/X_inter_pre',index_col = 0)
X_inter_train = pd.read_csv('data/X_inter_train',index_col = 0)
y_pre = pd.read_csv('data/y_pre',index_col = 0)
y_train = pd.read_csv('data/y_train',index_col = 0)

# %% [markdown]
# ## 1. Feature Selection and  Hyperparameter Tuning

# %% [markdown]
# Feature selection and hyperparameter tuning scheme will differ from models to models.
# For example, when selecting features for logistic regression, I wil use built in reuglarization method.
# Whereas, for support vector machine, I will use forward stepwise feature selection.
# I will explain this in detail right before I do feature selection and hyperparameter tuning.

# %% [markdown]
# - `paras` : a short for hyperparameters. This is where we will store tuned hyperparameters.<br>
# - `feats` : a short for featrues. This is where we will store selected features.<br>
# - `kfold` : a kfold object for 5-fold cross validation.

# %%
# tuned hyperparameters
paras = pd.DataFrame(data = {'accuracy_score' : [{},{},{},{},{},{},{}],
                             'precision' : [{},{},{},{},{},{},{}],
                             'true_positive_rate' : [{},{},{},{},{},{},{}],
                             'false_positive_rate' : [{},{},{},{},{},{},{}],
                             'f1' : [{},{},{},{},{},{},{}],
                             'roc_auc' : [{},{},{},{},{},{},{}]},
                     index=['Base','Log', 'LDA','SVM','DT','RF','XGB'])
# selected features
feats = pd.DataFrame(data = {'accuracy_score' : [[],[]],
                             'precision' : [[],[]],
                             'true_positive_rate' : [[],[]],
                             'false_positive_rate' : [[],[]],
                             'f1' : [[],[]],
                             'roc_auc' : [[],[]]},
                     index=['LDA','SVM'])
# kfold object
kfold = StratifiedKFold(n_splits = 5,
                        shuffle = True,
                        random_state = 623)

# %%
paras
# Out:
#      accuracy_score precision true_positive_rate false_positive_rate  f1  \
# Base             {}        {}                 {}                  {}  {}
# Log              {}        {}                 {}                  {}  {}
# LDA              {}        {}                 {}                  {}  {}
# SVM              {}        {}                 {}                  {}  {}
# DT               {}        {}                 {}                  {}  {}
# RF               {}        {}                 {}                  {}  {}
# XGB              {}        {}                 {}                  {}  {}
#
#      roc_auc
# Base      {}
# Log       {}
# LDA       {}
# SVM       {}
# DT        {}
# RF        {}
# XGB       {}

# %%
feats
# Out:
#     accuracy_score precision true_positive_rate false_positive_rate  f1  \
# LDA             []        []                 []                  []  []
# SVM             []        []                 []                  []  []
#
#     roc_auc
# LDA      []
# SVM      []

# %% [markdown]
# ### - Baseline Model-

# %% [markdown]
# - Our baseline model identically predicts all prior authorizaitons to be approved.
# - There is no hyperparameter to tune or features to select for this model.

# %% [markdown]
# ### -Logistic Regression-

# %% [markdown]
# - For feature selection, we use built in regularization method.
# - we will tune regularization constant `C` and the `penalty` function via cross validation.
# - Note that we are using interaction terms of the pairs (`bin`, `drug`), (`tried_and_faild`,`drug`),(`contraindication`,`drug`).
# - we will be using `X_pre` and `y_pre` for the cross validation.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# hyperparameters
Cs = [.01, .1, 1, 10, 100]
penalties = ['none', 'l1','l2','elasticnet']
# cross validation key performance indicators
acses = np.zeros((5, len(Cs),len(penalties)))
pres = np.zeros((5, len(Cs),len(penalties)))
tprs = np.zeros((5, len(Cs),len(penalties)))
fprs = np.zeros((5, len(Cs),len(penalties)))
f1s = np.zeros((5, len(Cs),len(penalties)))
aucs = np.zeros((5, len(Cs),len(penalties)))

# %%
# hyperparameter tuning via cross validation
i=0
for train_index, test_index in kfold.split(X_inter_pre, y_pre) :
    j=0
    # loop through various regularization constants
    for C in Cs :
        k=0
        # loop through various penalty functions
        for penalty in penalties :
            X_tt = X_inter_pre.iloc[train_index, :].copy()
            X_ho = X_inter_pre.iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            # we have to use different solver for different penalty function
            if penalty == 'l1' :
                log_reg = LogisticRegression(penalty = penalty, C=C, solver = 'liblinear', max_iter = 100)
            elif penalty == 'elasticnet' :
                log_reg = LogisticRegression(penalty = penalty, C=C, solver = 'saga', max_iter = 100, l1_ratio = .5)
            else:
                log_reg = LogisticRegression(penalty = penalty, C=C, max_iter = 100)
                
            log_reg.fit(X_tt.values, y_tt.values)
            pred = log_reg.predict(X_ho.values)
            pred_proba = log_reg.predict_proba(X_ho.values)[:, 1]
            
            acses[i,j,k] = accuracy_score(y_ho.values, pred)
            conf_mat = confusion_matrix(y_ho, pred)
            pres[i,j,k] = precision_score(y_ho, pred)
            tprs[i,j,k] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
            fprs[i,j,k] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
            f1s[i,j,k] = f1_score(y_ho, pred)
            aucs[i,j,k] = roc_auc_score(y_ho, pred_proba)
            k=k+1
        j=j+1      
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'accuracy_score']['penalty'] = penalties[penalty_index]
paras.loc['Log', 'accuracy_score']['C'] = Cs[C_index]

# with respect to the precision
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'precision']['penalty'] =  penalties[penalty_index]
paras.loc['Log', 'precision']['C'] = Cs[C_index]

# with respect to the true positive rate
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'true_positive_rate']['penalty'] =  penalties[penalty_index]
paras.loc['Log', 'true_positive_rate']['C'] = Cs[C_index]

# with respect to the false positive rate
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'false_positive_rate']['penalty'] =  penalties[penalty_index]
paras.loc['Log', 'false_positive_rate']['C'] = Cs[C_index]

# with respect to the f1_score
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'f1']['penalty'] =  penalties[penalty_index]
paras.loc['Log', 'f1']['C'] = Cs[C_index]

# with respect to the roc_auc_score
cv = np.mean(aucs, axis = 0)
cv_max = np.max(np.max(cv, axis = 0),axis = 0)
penalty_index = np.argwhere(cv == cv_max)[0][1]
C_index = np.argwhere(cv == cv_max)[0][0]
paras.loc['Log', 'roc_auc']['penalty'] =  penalties[penalty_index]
paras.loc['Log', 'roc_auc']['C'] = Cs[C_index]

# %%
paras
# Out:
#                     accuracy_score                             precision  \
# Base                            {}                                    {}
# Log   {'penalty': 'l2', 'C': 0.01}  {'penalty': 'elasticnet', 'C': 0.01}
# LDA                             {}                                    {}
# SVM                             {}                                    {}
# DT                              {}                                    {}
# RF                              {}                                    {}
# XGB                             {}                                    {}
#
#                         true_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                                     {}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                        false_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                                     {}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                                         f1  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                                     {}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                                    roc_auc
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                                     {}
# DT                                      {}
# RF                                      {}
# XGB                                     {}

# %%
feats
# Out:
#     accuracy_score precision true_positive_rate false_positive_rate  f1  \
# LDA             []        []                 []                  []  []
# SVM             []        []                 []                  []  []
#
#     roc_auc
# LDA      []
# SVM      []

# %% [markdown]
# ### -Linear Discriminant Analysis-

# %% [markdown]
# - For feature selection, we will try every possible combination of features.
# - There is no hyperparameter to tune for this model.
# - we will be using `X_pre` and `y_pre` for hyperparameter tuning.

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# this function eats a list and spits out the list of all the possible sublists of the input list
def powerset(s):
    power_set = []
    x = len(s)
    for i in range(1 << x):
        power_set.append([s[j] for j in range(x) if (i & (1 << j))])
        
    return power_set[1:]

# %%
# list of sublists of features
models = powerset(['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication'])
# cross validation key performance indicators
acses = np.zeros((5,len(models)))
pres = np.zeros((5,len(models)))
tprs = np.zeros((5,len(models)))
fprs = np.zeros((5,len(models)))
f1s = np.zeros((5,len(models)))
aucs = np.zeros((5,len(models)))

# %%
models
# Out:
# [['bin'],
#  ['drug'],
#  ['bin', 'drug'],
#  ['correct_diagnosis'],
#  ['bin', 'correct_diagnosis'],
#  ['drug', 'correct_diagnosis'],
#  ['bin', 'drug', 'correct_diagnosis'],
#  ['tried_and_failed'],
#  ['bin', 'tried_and_failed'],
#  ['drug', 'tried_and_failed'],
#  ['bin', 'drug', 'tried_and_failed'],
#  ['correct_diagnosis', 'tried_and_failed'],
#  ['bin', 'correct_diagnosis', 'tried_and_failed'],
#  ['drug', 'correct_diagnosis', 'tried_and_failed'],
#  ['bin', 'drug', 'correct_diagnosis', 'tried_and_failed'],
#  ['contraindication'],
#  ['bin', 'contraindication'],
#  ['drug', 'contraindication'],
#  ['bin', 'drug', 'contraindication'],
#  ['correct_diagnosis', 'contraindication'],
#  ['bin', 'correct_diagnosis', 'contraindication'],
#  ['drug', 'correct_diagnosis', 'contraindication'],
#  ['bin', 'drug', 'correct_diagnosis', 'contraindication'],
#  ['tried_and_failed', 'contraindication'],
#  ['bin', 'tried_and_failed', 'contraindication'],
#  ['drug', 'tried_and_failed', 'contraindication'],
#  ['bin', 'drug', 'tried_and_failed', 'contraindication'],
#  ['correct_diagnosis', 'tried_and_failed', 'contraindication'],
#  ['bin', 'correct_diagnosis', 'tried_and_failed', 'contraindication'],
#  ['drug', 'correct_diagnosis', 'tried_and_failed', 'contraindication'],
#  ['bin', 'drug', 'correct_diagnosis', 'tried_and_failed', 'contraindication']]

# %%
i=0
for train_index, test_index in kfold.split(X_train, y_train) : 
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    # loop over all possible combinations of features
    for j in range(len(models)) :        
        if 'bin' in models[j] :
            models[j] = [feature for feature in models[j] if feature != 'bin']
            models[j].extend(['417380','417614', '417740', '999001'])
        if 'drug' in models[j] : 
            models[j] = [feature for feature in models[j] if feature != 'drug']
            models[j].extend(['A','B','C'])
            
        lda = LinearDiscriminantAnalysis()
        lda.fit(X_tt[models[j]].values, y_tt.values)
        pred = lda.predict(X_ho[models[j]].values)
        pred_proba = lda.predict_proba(X_ho[models[j]].values)[:, 1]

        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, pred)
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','accuracy_score'] = models[np.argwhere(cv == max_cv)[0][0]]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','precision'] = models[np.argwhere(cv == max_cv)[0][0]]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','true_positive_rate'] = models[np.argwhere(cv == max_cv)[0][0]]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','false_positive_rate'] = models[np.argwhere(cv == max_cv)[0][0]]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','f1'] = models[np.argwhere(cv == max_cv)[0][0]]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
feats.loc['LDA','roc_auc'] = models[np.argwhere(cv == max_cv)[0][0]]

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM                                                 []
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM                                                 []
#
#                    true_positive_rate               false_positive_rate  \
# LDA  [417380, 417614, 417740, 999001]  [417380, 417614, 417740, 999001]
# SVM                                []                                []
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM                                                 []
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM                                                 []

# %% [markdown]
# ### -Support Vector Machine-

# %% [markdown]
# For support vector machine, the feature selection and hyperparameter tuning scheme is a little more complicated compared to the other models.
# - First we will loosely tune hyperparameters.
# - Next, using the hyperparameters previously found, we will select features by forward stepwise feature selection algorithm with respect to $R^2$ score.
# - Finally, using the features previously selected, we will fine tune hyperparameters again.
# - hyperparameter : margin
# - we will be using `X_pre` and `y_pre` for hyperparameter tuning and feature selection.

# %%
from sklearn.svm import SVC

# %%
# hyperprameters
margins = [.1, 1, 10]
# cross validation key performance indicators
acses = np.zeros((5,len(margins)))
pres = np.zeros((5,len(margins)))
tprs = np.zeros((5,len(margins)))
fprs = np.zeros((5,len(margins)))
f1s = np.zeros((5,len(margins)))
aucs = np.zeros((5,len(margins)))

# %%
# loose hyperparameter tuning via cross validation
i=0
for train_index, test_index in kfold.split(X_pre, y_pre) : 
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    # loop through various margins
    j=0
    for margin in margins : 
        svc = SVC(C = margin, max_iter = 10, probability = True)
        svc.fit(X_tt.values, y_tt.values)
        pred_proba = svc.decision_function(X_ho)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        
        acses[i,j] = accuracy_score(y_ho.values, 1*(pred_proba >= .5))
        conf_mat = confusion_matrix(y_ho, 1*(pred_proba >= .5))
        pres[i,j] = precision_score(y_ho, 1*(pred_proba >= .5))
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho, 1*(pred_proba >= .5))
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'accuracy_score']['margin'] =  margins[margin_index]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'precision']['margin'] =  margins[margin_index]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'true_positive_rate']['margin'] =  margins[margin_index]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'false_positive_rate']['margin'] =  margins[margin_index]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'f1']['margin'] =  margins[margin_index]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'roc_auc']['margin'] =  margins[margin_index]

# %%
# forward stepwise feature selection with respect to accuracy_score

R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    
    i=0
    # loop over all the features that have not been added
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()

            svc = SVC(C = paras.loc['SVM', 'accuracy_score']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
            
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2,axis=1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)


feats.loc['SVM','accuracy_score'] = added_features

# %%
#forward stepwise feature selection with respect to precision

R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    # loop over all the features that have not been added
    i=0
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            
            svc = SVC(C = paras.loc['SVM', 'precision']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
        
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2,axis=1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)


feats.loc['SVM','precision'] = added_features

# %%
#forward stepwise feature selection with respect to true_positive_rate

R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    # loop over all the features that have not been added
    i=0
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            
            svc = SVC(C = paras.loc['SVM', 'true_positive_rate']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
        
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2,axis=1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)


feats.loc['SVM','true_positive_rate'] = added_features

# %%
#forward stepwise feature selection with respect to false_positive_rate
R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    # loop over all the features that have not been added
    i=0
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            
            svc = SVC(C = paras.loc['SVM', 'false_positive_rate']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
         
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2,axis=1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)


feats.loc['SVM','false_positive_rate'] = added_features

# %%
#forward stepwise feature selection with respect to f1
R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    # loop over all the features that have not been added
    i=0
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            
            svc = SVC(C = paras.loc['SVM', 'f1']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
     
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2, axis = 1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)


feats.loc['SVM','f1'] = added_features

# %%
#forward stepwise feature selection with respect to roc_auc
R2 = -1
added_features = []
candidate_features = ['bin', 'drug','correct_diagnosis', 'tried_and_failed', 'contraindication']
# loop while R^2 is less than .9 and there are features that have not been added
while(R2 <= .9 and candidate_features) : 
    
    temp_features = added_features.copy()
    cv_R2 = np.zeros((len(candidate_features),5))
    # loop over all the features that have not been added
    i=0
    for x in candidate_features : 
        if x == 'bin' : 
            temp_features.extend(['417380','417614','417740','999001'])
        elif x == 'drug' : 
            temp_features.extend(['A','B','C'])
        else : 
            temp_features.append(x)
        j=0
        for train_index, test_index in kfold.split(X_pre, y_pre) :
            X_tt = X_pre[temp_features].iloc[train_index, :].copy()
            X_ho = X_pre[temp_features].iloc[test_index, :].copy()
            y_tt = y_pre.iloc[train_index].copy()
            y_ho = y_pre.iloc[test_index].copy()
            
            svc = SVC(C = paras.loc['SVM', 'roc_auc']['margin'] , max_iter = 10, probability = True)
            svc.fit(X_tt.values, y_tt.values)
            pred_proba = svc.decision_function(X_ho)
            pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
            cv_R2[i,j] = r2_score(y_ho, pred_proba)
            j=j+1
      
        if x == 'bin' : 
            temp_features.remove('417380')
            temp_features.remove('417614')
            temp_features.remove('417740')
            temp_features.remove('999001')
        elif x == 'drug' : 
            temp_features.remove('A')
            temp_features.remove('B')
            temp_features.remove('C')
        else : 
            temp_features.remove(x)
        i=i+1
    R2 = np.max(np.mean(cv_R2, axis = 1))
    best_feature = candidate_features[np.argwhere(np.mean(cv_R2,axis=1) == R2)[0][0]]
    candidate_features.remove(best_feature)
    if best_feature == 'bin' : 
        added_features.extend(['417380','417614','417740','999001'])
    elif best_feature == 'drug' : 
        added_features.extend(['A','B','C'])
    else : 
        added_features.append(best_feature)
        
feats.loc['SVM','roc_auc'] = added_features

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %%
# final hyperparameter tuning
i=0
for train_index, test_index in kfold.split(X_pre, y_pre) : 
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    # loop through various margins
    j=0
    for margin in margins : 
        svc = SVC(C = margin, max_iter = 10, probability = True)
        svc.fit(X_tt.loc[:,feats.loc['SVM','accuracy_score']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','accuracy_score']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        acses[i,j] = accuracy_score(y_ho.values, 1*(pred_proba >= .5))
        
        svc.fit(X_tt.loc[:,feats.loc['SVM','precision']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','precision']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        pres[i,j] = precision_score(y_ho, 1*(pred_proba >= .5))
        
        svc.fit(X_tt.loc[:,feats.loc['SVM','true_positive_rate']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','true_positive_rate']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        conf_mat = confusion_matrix(y_ho, 1*(pred_proba >= .5))
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        
        svc.fit(X_tt.loc[:,feats.loc['SVM','false_positive_rate']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','false_positive_rate']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        conf_mat = confusion_matrix(y_ho, 1*(pred_proba >= .5))
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        
        svc.fit(X_tt.loc[:,feats.loc['SVM','f1']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','f1']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        f1s[i,j] = f1_score(y_ho, 1*(pred_proba >= .5))
        
        svc.fit(X_tt.loc[:,feats.loc['SVM','roc_auc']].values, y_tt.values)
        pred_proba = svc.decision_function(X_ho.loc[:,feats.loc['SVM','roc_auc']].values)
        pred_proba = (pred_proba - pred_proba.min()) / (pred_proba.max() - pred_proba.min())
        aucs[i,j] = roc_auc_score(y_ho, pred_proba)
        j=j+1
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'accuracy_score']['margin'] =  margins[margin_index]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'precision']['margin'] =  margins[margin_index]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'true_positive_rate']['margin'] =  margins[margin_index]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'false_positive_rate']['margin'] =  margins[margin_index]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'f1']['margin'] =  margins[margin_index]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
margin_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['SVM', 'roc_auc']['margin'] =  margins[margin_index]

# %%
paras
# Out:
#                     accuracy_score                             precision  \
# Base                            {}                                    {}
# Log   {'penalty': 'l2', 'C': 0.01}  {'penalty': 'elasticnet', 'C': 0.01}
# LDA                             {}                                    {}
# SVM                 {'margin': 10}                       {'margin': 0.1}
# DT                              {}                                    {}
# RF                              {}                                    {}
# XGB                             {}                                    {}
#
#                         true_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                        false_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                                         f1  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT                                      {}
# RF                                      {}
# XGB                                     {}
#
#                                    roc_auc
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                        {'margin': 0.1}
# DT                                      {}
# RF                                      {}
# XGB                                     {}

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %% [markdown]
# ### -Decision Tree-

# %% [markdown]
# - For feature selection, we use built in pruning methods <br>
# &emsp; -For pre- pruning, we use max_depth<br>
# &emsp; -for post-pruning, we use cost complexity pruning
# - hyperparameters : max_depth, cost_complexity constant alpha
# - we will be using `X_pre` and `y_pre` for hyperparameter tuning and feature selection.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt= DecisionTreeClassifier()
# hyperparameters
# cost complexity score constant
path = dt.cost_complexity_pruning_path(X_pre,y_pre)
alphas = np.append(path.ccp_alphas[:5],path.ccp_alphas[-5:])
# cross validation key performance indicators
max_depths = np.linspace(1, 32, 32, endpoint=True)
acses = np.zeros((5,len(max_depths), len(alphas)))
pres = np.zeros((5,len(max_depths), len(alphas)))
tprs = np.zeros((5,len(max_depths), len(alphas)))
fprs = np.zeros((5,len(max_depths), len(alphas)))
f1s = np.zeros((5,len(max_depths), len(alphas)))
aucs = np.zeros((5,len(max_depths), len(alphas)))

# %%
i=0
for train_index, test_index in kfold.split(X_pre, y_pre) : 
    # data split into training set and holdout set
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    j=0
    # loop through various max_depths 
    for max_depth in max_depths :
        k=0
        # loop through various cost complexity score constants
        for ccp_alpha in alphas :
            # fit the model against the training data and transform the holdout data
            dt = DecisionTreeClassifier(max_depth = max_depth)
            dt.fit(X_tt.values, y_tt.values)
            pred = dt.predict(X_ho.values)
            pred_proba = dt.predict_proba(X_ho.values)[:,1]
            #store various scores for each fold of the cross validation
            acses[i,j,k] = accuracy_score(y_ho.values, pred)
            conf_mat = confusion_matrix(y_ho, pred)
            pres[i,j,k] = precision_score(y_ho, pred)
            tprs[i,j,k] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
            fprs[i,j,k] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
            f1s[i,j,k] = f1_score(y_ho, pred)
            aucs[i,j,k] = roc_auc_score(y_ho, pred_proba)
            k=k+1
        j=j+1
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'accuracy_score']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'accuracy_score']['ccp_alpha'] = alphas[alpha_index]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'precision']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'precision']['ccp_alpha'] = alphas[alpha_index]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'true_positive_rate']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'true_positive_rate']['ccp_alpha'] = alphas[alpha_index]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'false_positive_rate']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'false_positive_rate']['ccp_alpha'] = alphas[alpha_index]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'f1']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'f1']['ccp_alpha'] = alphas[alpha_index]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
alpha_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['DT', 'roc_auc']['max_depth'] = max_depths[depth_index]
paras.loc['DT', 'roc_auc']['ccp_alpha'] = alphas[alpha_index]

# %%
paras
# Out:
#                             accuracy_score  \
# Base                                    {}
# Log           {'penalty': 'l2', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}
#
#                                  precision  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                        {'margin': 0.1}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}
#
#                         true_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}
#
#                        false_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}
#
#                                         f1  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}
#
#                                    roc_auc
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                        {'margin': 0.1}
# DT    {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                                      {}
# XGB                                     {}

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %% [markdown]
# ### -Random Forest-

# %% [markdown]
# - For feature selection we use built in pruning method :<br>
# \-For pre- pruning, we use max_depth.<br>
# \-Unlike decision tree model,we do not perform post_pruning using cost_complexity_score because post_pruning usually sub-optimize the performance of ensemble methods
# - hyperparamete : max_depth
# - We will be using `X_pre` and `y_pre` for hyperparameter tuning and feature selection.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# hyperparameters
max_depths = [3 ,4, 5, 6]
# cross validation key performance indicators
acses = np.zeros((5,len(max_depths)))
pres = np.zeros((5,len(max_depths)))
tprs = np.zeros((5,len(max_depths)))
fprs = np.zeros((5,len(max_depths)))
f1s = np.zeros((5,len(max_depths)))
aucs = np.zeros((5,len(max_depths)))

# %%
# hyperparameter tuning via cross validation
i=0
for train_index, test_index in kfold.split(X_pre, y_pre) :
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    j=0
    # loop through various max_depths
    for max_depth in max_depths :
        rf = RandomForestClassifier(n_estimators = 100,
                                    max_depth = max_depth,
                                    random_state = 623)
        rf.fit(X_tt.values,y_tt.values)
        pred = rf.predict(X_ho.values)
        pred_proba = rf.predict_proba(X_ho.values)[:,1]
        
        acses[i,j] = accuracy_score(y_ho.values, pred)
        conf_mat = confusion_matrix(y_ho, pred)
        pres[i,j] = precision_score(y_ho, pred)
        tprs[i,j] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
        fprs[i,j] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
        f1s[i,j] = f1_score(y_ho.values, pred)
        aucs[i,j] = roc_auc_score(y_ho.values, pred_proba)
        j=j+1
    i=i+1

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'accuracy_score']['max_depth'] = max_depths[depth_index]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'precision']['max_depth'] = max_depths[depth_index]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'true_positive_rate']['max_depth'] = max_depths[depth_index]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'false_positive_rate']['max_depth'] = max_depths[depth_index]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'f1']['max_depth'] = max_depths[depth_index]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(cv, axis = 0)
depth_index = np.argwhere(cv == max_cv)[0][0]
paras.loc['RF', 'roc_auc']['max_depth'] = max_depths[depth_index]

# %%
paras
# Out:
#                             accuracy_score  \
# Base                                    {}
# Log           {'penalty': 'l2', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB                                     {}
#
#                                  precision  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                        {'margin': 0.1}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB                                     {}
#
#                         true_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 3}
# XGB                                     {}
#
#                        false_positive_rate  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 3}
# XGB                                     {}
#
#                                         f1  \
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB                                     {}
#
#                                    roc_auc
# Base                                    {}
# Log   {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                     {}
# SVM                        {'margin': 0.1}
# DT    {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB                                     {}

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %% [markdown]
# ### -XGBoost-

# %% [markdown]
# - For feature selection, we use built in pre-pruning method by fixing max_depth of individual tree.
# - hyperparameter tuning : learning rates, max_depth
# - We will be using `X_pre` and `y_pre` for hyperparameter tuning and feature selection.

# %%
from xgboost import XGBClassifier

# %%
# hyperparameters
learning_rates = [0.01, 0.1, 1, 10, 100]
max_depths = [3, 5, 10]
# cross validation key performance indicators
acses = np.zeros((5,len(learning_rates), len(max_depths)))
pres = np.zeros((5,len(learning_rates), len(max_depths)))
tprs = np.zeros((5,len(learning_rates), len(max_depths)))
fprs = np.zeros((5,len(learning_rates), len(max_depths)))
f1s = np.zeros((5,len(learning_rates), len(max_depths)))
aucs = np.zeros((5,len(learning_rates), len(max_depths)))

# %%
# hyperparameter tuning via cross validation
i=0
for train_index, test_index in kfold.split(X_pre, y_pre) : 
    X_tt = X_pre.iloc[train_index, :].copy()
    X_ho = X_pre.iloc[test_index, :].copy()
    y_tt = y_pre.iloc[train_index].copy()
    y_ho = y_pre.iloc[test_index].copy()
    # loop through various learning rates
    j=0
    for learning_rate in learning_rates :
        # loop through various max_depths
        k=0
        for max_depth in max_depths :
            xgb = XGBClassifier(learning_rate = learning_rate,
                                    max_depth = max_depth,
                                    use_label_encoder=False,
                                    n_estimators = 100,
                                    random_state = 623,
                                    eval_metric = 'logloss')
            xgb.fit(X_tt.values, y_tt.values,
                    early_stopping_rounds = 3,
                    eval_set = [(X_ho.values, y_ho.values)])
            pred = xgb.predict(X_ho.values)
            pred_proba = xgb.predict_proba(X_ho.values)[:,1]
            
            acses[i,j,k] = accuracy_score(y_ho.values, pred)
            conf_mat = confusion_matrix(y_ho, pred)
            pres[i,j,k] = precision_score(y_ho, pred)
            tprs[i,j,k] = conf_mat[1,1]/(conf_mat[1,0] + conf_mat[1,1])
            fprs[i,j,k] = conf_mat[0,1]/(conf_mat[0,0] + conf_mat[0,1])
            f1s[i,j,k] = f1_score(y_ho, pred)
            aucs[i,j,k] = roc_auc_score(y_ho, pred_proba)
            k=k+1
        j=j+1
    i=i+1
# Out:
# [0]	validation_0-logloss:0.68990
# [1]	validation_0-logloss:0.68680
# [2]	validation_0-logloss:0.68372
# [3]	validation_0-logloss:0.68071
# [4]	validation_0-logloss:0.67771
# [5]	validation_0-logloss:0.67477
# [6]	validation_0-logloss:0.67193
# [7]	validation_0-logloss:0.66914
# [8]	validation_0-logloss:0.66637
# [9]	validation_0-logloss:0.66372
# [10]	validation_0-logloss:0.66108
# [11]	validation_0-logloss:0.65845
# [12]	validation_0-logloss:0.65594
# [13]	validation_0-logloss:0.65343
# [14]	validation_0-logloss:0.65100
# [15]	validation_0-logloss:0.64857
# [16]	validation_0-logloss:0.64623
# [17]	validation_0-logloss:0.64391
# [18]	validation_0-logloss:0.64166
# [19]	validation_0-logloss:0.63941
# [20]	validation_0-logloss:0.63723
# [21]	validation_0-logloss:0.63507
# [22]	validation_0-logloss:0.63293
# [23]	validation_0-logloss:0.63086
# [24]	validation_0-logloss:0.62883
# [25]	validation_0-logloss:0.62681
# [26]	validation_0-logloss:0.62483
# [27]	validation_0-logloss:0.62292
# [28]	validation_0-logloss:0.62097
# [29]	validation_0-logloss:0.61911
# [30]	validation_0-logloss:0.61725
# [31]	validation_0-logloss:0.61544
# [32]	validation_0-logloss:0.61366
# [33]	validation_0-logloss:0.61190
# [34]	validation_0-logloss:0.61016
# [35]	validation_0-logloss:0.60788
# [36]	validation_0-logloss:0.60621
# [37]	validation_0-logloss:0.60455
# [38]	validation_0-logloss:0.60293
# [39]	validation_0-logloss:0.60077
# [40]	validation_0-logloss:0.59919
# [41]	validation_0-logloss:0.59762
# [42]	validation_0-logloss:0.59613
# [43]	validation_0-logloss:0.59406
# [44]	validation_0-logloss:0.59257
# [45]	validation_0-logloss:0.59114
# [46]	validation_0-logloss:0.58973
# [47]	validation_0-logloss:0.58790
# [48]	validation_0-logloss:0.58651
# [49]	validation_0-logloss:0.58515
# [50]	validation_0-logloss:0.58397
# [51]	validation_0-logloss:0.58207
# [52]	validation_0-logloss:0.58077
# [53]	validation_0-logloss:0.57965
# [54]	validation_0-logloss:0.57854
# [55]	validation_0-logloss:0.57730
# [56]	validation_0-logloss:0.57549
# [57]	validation_0-logloss:0.57445
# [58]	validation_0-logloss:0.57326
# [59]	validation_0-logloss:0.57225
# [60]	validation_0-logloss:0.57054
# [61]	validation_0-logloss:0.56939
# [62]	validation_0-logloss:0.56843
# [63]	validation_0-logloss:0.56729
# [64]	validation_0-logloss:0.56620
# [65]	validation_0-logloss:0.56476
# [66]	validation_0-logloss:0.56383
# [67]	validation_0-logloss:0.56279
# [68]	validation_0-logloss:0.56175
# [69]	validation_0-logloss:0.56089
# [70]	validation_0-logloss:0.55935
# [71]	validation_0-logloss:0.55834
# [72]	validation_0-logloss:0.55751
# [73]	validation_0-logloss:0.55656
# [74]	validation_0-logloss:0.55523
# [75]	validation_0-logloss:0.55427
# [76]	validation_0-logloss:0.55337
# [77]	validation_0-logloss:0.55257
# [78]	validation_0-logloss:0.55182
# [79]	validation_0-logloss:0.55044
# [80]	validation_0-logloss:0.54953
# [81]	validation_0-logloss:0.54883
# [82]	validation_0-logloss:0.54798
# [83]	validation_0-logloss:0.54712
# [84]	validation_0-logloss:0.54593
# [85]	validation_0-logloss:0.54513
# [86]	validation_0-logloss:0.54433
# [87]	validation_0-logloss:0.54366
# [88]	validation_0-logloss:0.54241
# [89]	validation_0-logloss:0.54176
# [90]	validation_0-logloss:0.54103
# [91]	validation_0-logloss:0.54040
# [92]	validation_0-logloss:0.53963
# [93]	validation_0-logloss:0.53902
# [94]	validation_0-logloss:0.53785
# [95]	validation_0-logloss:0.53721
# [96]	validation_0-logloss:0.53666
# [97]	validation_0-logloss:0.53608
# [98]	validation_0-logloss:0.53501
# [99]	validation_0-logloss:0.53436
# [0]	validation_0-logloss:0.68891
# [1]	validation_0-logloss:0.68474
# [2]	validation_0-logloss:0.68064
# [3]	validation_0-logloss:0.67665
# [4]	validation_0-logloss:0.67268
# [5]	validation_0-logloss:0.66879
# [6]	validation_0-logloss:0.66496
# [7]	validation_0-logloss:0.66122
# [8]	validation_0-logloss:0.65754
# [9]	validation_0-logloss:0.65390
# [10]	validation_0-logloss:0.65038
# [11]	validation_0-logloss:0.64688
# [12]	validation_0-logloss:0.64345
# [13]	validation_0-logloss:0.64011
# [14]	validation_0-logloss:0.63680
# [15]	validation_0-logloss:0.63353
# [16]	validation_0-logloss:0.63035
# [17]	validation_0-logloss:0.62721
# [18]	validation_0-logloss:0.62414
# [19]	validation_0-logloss:0.62111
# [20]	validation_0-logloss:0.61811
# [21]	validation_0-logloss:0.61517
# [22]	validation_0-logloss:0.61230
# [23]	validation_0-logloss:0.60945
# [24]	validation_0-logloss:0.60666
# [25]	validation_0-logloss:0.60394
# [26]	validation_0-logloss:0.60123
# [27]	validation_0-logloss:0.59856
# [28]	validation_0-logloss:0.59594
# [29]	validation_0-logloss:0.59337
# [30]	validation_0-logloss:0.59084
# [31]	validation_0-logloss:0.58836
# [32]	validation_0-logloss:0.58590
# [33]	validation_0-logloss:0.58348
# [34]	validation_0-logloss:0.58112
# [35]	validation_0-logloss:0.57876
# [36]	validation_0-logloss:0.57647
# [37]	validation_0-logloss:0.57421
# [38]	validation_0-logloss:0.57198
# [39]	validation_0-logloss:0.56978
# [40]	validation_0-logloss:0.56761
# [41]	validation_0-logloss:0.56549
# [42]	validation_0-logloss:0.56335
# [43]	validation_0-logloss:0.56126
# [44]	validation_0-logloss:0.55917
# [45]	validation_0-logloss:0.55715
# [46]	validation_0-logloss:0.55515
# [47]	validation_0-logloss:0.55317
# [48]	validation_0-logloss:0.55124
# [49]	validation_0-logloss:0.54931
# [50]	validation_0-logloss:0.54744
# [51]	validation_0-logloss:0.54561
# [52]	validation_0-logloss:0.54381
# [53]	validation_0-logloss:0.54204
# [54]	validation_0-logloss:0.54028
# [55]	validation_0-logloss:0.53861
# [56]	validation_0-logloss:0.53692
# [57]	validation_0-logloss:0.53529
# [58]	validation_0-logloss:0.53359
# [59]	validation_0-logloss:0.53199
# [60]	validation_0-logloss:0.53043
# [61]	validation_0-logloss:0.52884
# [62]	validation_0-logloss:0.52731
# [63]	validation_0-logloss:0.52577
# [64]	validation_0-logloss:0.52424
# [65]	validation_0-logloss:0.52276
# [66]	validation_0-logloss:0.52131
# [67]	validation_0-logloss:0.51985
# [68]	validation_0-logloss:0.51807
# [69]	validation_0-logloss:0.51663
# [70]	validation_0-logloss:0.51515
# [71]	validation_0-logloss:0.51379
# [72]	validation_0-logloss:0.51246
# [73]	validation_0-logloss:0.51078
# [74]	validation_0-logloss:0.50939
# [75]	validation_0-logloss:0.50794
# [76]	validation_0-logloss:0.50662
# [77]	validation_0-logloss:0.50536
# [78]	validation_0-logloss:0.50399
# [79]	validation_0-logloss:0.50276
# [80]	validation_0-logloss:0.50141
# [81]	validation_0-logloss:0.49997
# [82]	validation_0-logloss:0.49861
# [83]	validation_0-logloss:0.49711
# [84]	validation_0-logloss:0.49596
# [85]	validation_0-logloss:0.49450
# [86]	validation_0-logloss:0.49322
# [87]	validation_0-logloss:0.49180
# [88]	validation_0-logloss:0.49038
# [89]	validation_0-logloss:0.48916
# [90]	validation_0-logloss:0.48794
# [91]	validation_0-logloss:0.48677
# [92]	validation_0-logloss:0.48529
# [93]	validation_0-logloss:0.48414
# [94]	validation_0-logloss:0.48292
# [95]	validation_0-logloss:0.48163
# [96]	validation_0-logloss:0.48050
# [97]	validation_0-logloss:0.47925
# [98]	validation_0-logloss:0.47800
# [99]	validation_0-logloss:0.47696
# [0]	validation_0-logloss:0.68808
# [1]	validation_0-logloss:0.68313
# [2]	validation_0-logloss:0.67826
# [3]	validation_0-logloss:0.67350
# [4]	validation_0-logloss:0.66883
# [5]	validation_0-logloss:0.66424
# [6]	validation_0-logloss:0.65975
# [7]	validation_0-logloss:0.65533
# [8]	validation_0-logloss:0.65100
# [9]	validation_0-logloss:0.64676
# [10]	validation_0-logloss:0.64259
# [11]	validation_0-logloss:0.63850
# [12]	validation_0-logloss:0.63448
# [13]	validation_0-logloss:0.63055
# [14]	validation_0-logloss:0.62666
# [15]	validation_0-logloss:0.62287
# [16]	validation_0-logloss:0.61913
# [17]	validation_0-logloss:0.61546
# [18]	validation_0-logloss:0.61186
# [19]	validation_0-logloss:0.60833
# [20]	validation_0-logloss:0.60485
# [21]	validation_0-logloss:0.60142
# [22]	validation_0-logloss:0.59808
# [23]	validation_0-logloss:0.59478
# [24]	validation_0-logloss:0.59154
# [25]	validation_0-logloss:0.58834
# [26]	validation_0-logloss:0.58520
# [27]	validation_0-logloss:0.58213
# [28]	validation_0-logloss:0.57910
# [29]	validation_0-logloss:0.57612
# [30]	validation_0-logloss:0.57319
# [31]	validation_0-logloss:0.57031
# [32]	validation_0-logloss:0.56747
# [33]	validation_0-logloss:0.56469
# [34]	validation_0-logloss:0.56195
# [35]	validation_0-logloss:0.55926
# [36]	validation_0-logloss:0.55661
# [37]	validation_0-logloss:0.55399
# [38]	validation_0-logloss:0.55142
# [39]	validation_0-logloss:0.54890
# [40]	validation_0-logloss:0.54641
# [41]	validation_0-logloss:0.54396
# [42]	validation_0-logloss:0.54156
# [43]	validation_0-logloss:0.53919
# [44]	validation_0-logloss:0.53686
# [45]	validation_0-logloss:0.53456
# [46]	validation_0-logloss:0.53231
# [47]	validation_0-logloss:0.53009
# [48]	validation_0-logloss:0.52790
# [49]	validation_0-logloss:0.52573
# [50]	validation_0-logloss:0.52363
# [51]	validation_0-logloss:0.52153
# [52]	validation_0-logloss:0.51947
# [53]	validation_0-logloss:0.51744
# [54]	validation_0-logloss:0.51545
# [55]	validation_0-logloss:0.51348
# [56]	validation_0-logloss:0.51155
# [57]	validation_0-logloss:0.50964
# [58]	validation_0-logloss:0.50776
# [59]	validation_0-logloss:0.50590
# [60]	validation_0-logloss:0.50410
# [61]	validation_0-logloss:0.50230
# [62]	validation_0-logloss:0.50053
# [63]	validation_0-logloss:0.49879
# [64]	validation_0-logloss:0.49709
# [65]	validation_0-logloss:0.49540
# [66]	validation_0-logloss:0.49372
# [67]	validation_0-logloss:0.49209
# [68]	validation_0-logloss:0.49048
# [69]	validation_0-logloss:0.48887
# [70]	validation_0-logloss:0.48730
# [71]	validation_0-logloss:0.48576
# [72]	validation_0-logloss:0.48423
# [73]	validation_0-logloss:0.48273
# [74]	validation_0-logloss:0.48125
# [75]	validation_0-logloss:0.47980
# [76]	validation_0-logloss:0.47836
# [77]	validation_0-logloss:0.47694
# [78]	validation_0-logloss:0.47554
# [79]	validation_0-logloss:0.47417
# [80]	validation_0-logloss:0.47281
# [81]	validation_0-logloss:0.47147
# [82]	validation_0-logloss:0.47017
# [83]	validation_0-logloss:0.46885
# [84]	validation_0-logloss:0.46757
# [85]	validation_0-logloss:0.46631
# [86]	validation_0-logloss:0.46507
# [87]	validation_0-logloss:0.46384
# [88]	validation_0-logloss:0.46263
# [89]	validation_0-logloss:0.46144
# [90]	validation_0-logloss:0.46026
# [91]	validation_0-logloss:0.45909
# [92]	validation_0-logloss:0.45795
# [93]	validation_0-logloss:0.45682
# [94]	validation_0-logloss:0.45571
# [95]	validation_0-logloss:0.45462
# [96]	validation_0-logloss:0.45353
# [97]	validation_0-logloss:0.45248
# [98]	validation_0-logloss:0.45142
# [99]	validation_0-logloss:0.45038
# [0]	validation_0-logloss:0.66246
# [1]	validation_0-logloss:0.63746
# [2]	validation_0-logloss:0.61687
# [3]	validation_0-logloss:0.59932
# [4]	validation_0-logloss:0.57903
# [5]	validation_0-logloss:0.56799
# [6]	validation_0-logloss:0.55698
# [7]	validation_0-logloss:0.54765
# [8]	validation_0-logloss:0.54096
# [9]	validation_0-logloss:0.52917
# [10]	validation_0-logloss:0.51677
# [11]	validation_0-logloss:0.50433
# [12]	validation_0-logloss:0.50042
# [13]	validation_0-logloss:0.49344
# [14]	validation_0-logloss:0.48361
# [15]	validation_0-logloss:0.47557
# [16]	validation_0-logloss:0.47310
# [17]	validation_0-logloss:0.46832
# [18]	validation_0-logloss:0.46641
# [19]	validation_0-logloss:0.45900
# [20]	validation_0-logloss:0.45328
# [21]	validation_0-logloss:0.44840
# [22]	validation_0-logloss:0.44712
# [23]	validation_0-logloss:0.44290
# [24]	validation_0-logloss:0.43893
# [25]	validation_0-logloss:0.43540
# [26]	validation_0-logloss:0.43290
# [27]	validation_0-logloss:0.42967
# [28]	validation_0-logloss:0.42684
# [29]	validation_0-logloss:0.42493
# [30]	validation_0-logloss:0.41898
# [31]	validation_0-logloss:0.41676
# [32]	validation_0-logloss:0.41524
# [33]	validation_0-logloss:0.41338
# [34]	validation_0-logloss:0.41146
# [35]	validation_0-logloss:0.41102
# [36]	validation_0-logloss:0.40675
# [37]	validation_0-logloss:0.40635
# [38]	validation_0-logloss:0.40603
# [39]	validation_0-logloss:0.40236
# [40]	validation_0-logloss:0.40128
# [41]	validation_0-logloss:0.40037
# [42]	validation_0-logloss:0.40002
# [43]	validation_0-logloss:0.39837
# [44]	validation_0-logloss:0.39807
# [45]	validation_0-logloss:0.39662
# [46]	validation_0-logloss:0.39595
# [47]	validation_0-logloss:0.39570
# [48]	validation_0-logloss:0.39528
# [49]	validation_0-logloss:0.39515
# [50]	validation_0-logloss:0.39394
# [51]	validation_0-logloss:0.39376
# [52]	validation_0-logloss:0.39298
# [53]	validation_0-logloss:0.39189
# [54]	validation_0-logloss:0.39163
# [55]	validation_0-logloss:0.39139
# [56]	validation_0-logloss:0.38921
# [57]	validation_0-logloss:0.38863
# [58]	validation_0-logloss:0.38826
# [59]	validation_0-logloss:0.38814
# [60]	validation_0-logloss:0.38795
# [61]	validation_0-logloss:0.38717
# [62]	validation_0-logloss:0.38653
# [63]	validation_0-logloss:0.38586
# [64]	validation_0-logloss:0.38559
# [65]	validation_0-logloss:0.38548
# [66]	validation_0-logloss:0.38488
# [67]	validation_0-logloss:0.38484
# [68]	validation_0-logloss:0.38472
# [69]	validation_0-logloss:0.38420
# [70]	validation_0-logloss:0.38370
# [71]	validation_0-logloss:0.38367
# [72]	validation_0-logloss:0.38234
# [73]	validation_0-logloss:0.38208
# [74]	validation_0-logloss:0.38178
# [75]	validation_0-logloss:0.38175
# [76]	validation_0-logloss:0.38127
# [77]	validation_0-logloss:0.38113
# [78]	validation_0-logloss:0.38090
# [79]	validation_0-logloss:0.38084
# [80]	validation_0-logloss:0.38045
# [81]	validation_0-logloss:0.38012
# [82]	validation_0-logloss:0.38011
# [83]	validation_0-logloss:0.37966
# [84]	validation_0-logloss:0.37948
# [85]	validation_0-logloss:0.37917
# [86]	validation_0-logloss:0.37892
# [87]	validation_0-logloss:0.37877
# [88]	validation_0-logloss:0.37865
# [89]	validation_0-logloss:0.37862
# [90]	validation_0-logloss:0.37836
# [91]	validation_0-logloss:0.37831
# [92]	validation_0-logloss:0.37820
# [93]	validation_0-logloss:0.37787
# [94]	validation_0-logloss:0.37779
# [95]	validation_0-logloss:0.37756
# [96]	validation_0-logloss:0.37740
# [97]	validation_0-logloss:0.37733
# [98]	validation_0-logloss:0.37730
# [99]	validation_0-logloss:0.37726
# [0]	validation_0-logloss:0.65254
# [1]	validation_0-logloss:0.61879
# [2]	validation_0-logloss:0.59079
# [3]	validation_0-logloss:0.56697
# [4]	validation_0-logloss:0.54685
# [5]	validation_0-logloss:0.52909
# [6]	validation_0-logloss:0.51420
# [7]	validation_0-logloss:0.50036
# [8]	validation_0-logloss:0.48726
# [9]	validation_0-logloss:0.47569
# [10]	validation_0-logloss:0.46435
# [11]	validation_0-logloss:0.45528
# [12]	validation_0-logloss:0.44765
# [13]	validation_0-logloss:0.44056
# [14]	validation_0-logloss:0.43218
# [15]	validation_0-logloss:0.42720
# [16]	validation_0-logloss:0.42055
# [17]	validation_0-logloss:0.41477
# [18]	validation_0-logloss:0.40974
# [19]	validation_0-logloss:0.40680
# [20]	validation_0-logloss:0.40342
# [21]	validation_0-logloss:0.40050
# [22]	validation_0-logloss:0.39805
# [23]	validation_0-logloss:0.39574
# [24]	validation_0-logloss:0.39387
# [25]	validation_0-logloss:0.39203
# [26]	validation_0-logloss:0.39050
# [27]	validation_0-logloss:0.38965
# [28]	validation_0-logloss:0.38887
# [29]	validation_0-logloss:0.38690
# [30]	validation_0-logloss:0.38581
# [31]	validation_0-logloss:0.38518
# [32]	validation_0-logloss:0.38366
# [33]	validation_0-logloss:0.38285
# [34]	validation_0-logloss:0.38163
# [35]	validation_0-logloss:0.38061
# [36]	validation_0-logloss:0.37983
# [37]	validation_0-logloss:0.37914
# [38]	validation_0-logloss:0.37872
# [39]	validation_0-logloss:0.37797
# [40]	validation_0-logloss:0.37780
# [41]	validation_0-logloss:0.37745
# [42]	validation_0-logloss:0.37686
# [43]	validation_0-logloss:0.37658
# [44]	validation_0-logloss:0.37610
# [45]	validation_0-logloss:0.37580
# [46]	validation_0-logloss:0.37550
# [47]	validation_0-logloss:0.37534
# [48]	validation_0-logloss:0.37519
# [49]	validation_0-logloss:0.37502
# [50]	validation_0-logloss:0.37487
# [51]	validation_0-logloss:0.37474
# [52]	validation_0-logloss:0.37466
# [53]	validation_0-logloss:0.37439
# [54]	validation_0-logloss:0.37426
# [55]	validation_0-logloss:0.37419
# [56]	validation_0-logloss:0.37411
# [57]	validation_0-logloss:0.37395
# [58]	validation_0-logloss:0.37385
# [59]	validation_0-logloss:0.37369
# [60]	validation_0-logloss:0.37359
# [61]	validation_0-logloss:0.37354
# [62]	validation_0-logloss:0.37351
# [63]	validation_0-logloss:0.37339
# [64]	validation_0-logloss:0.37337
# [65]	validation_0-logloss:0.37330
# [66]	validation_0-logloss:0.37321
# [67]	validation_0-logloss:0.37317
# [68]	validation_0-logloss:0.37311
# [69]	validation_0-logloss:0.37306
# [70]	validation_0-logloss:0.37302
# [71]	validation_0-logloss:0.37298
# [72]	validation_0-logloss:0.37292
# [73]	validation_0-logloss:0.37286
# [74]	validation_0-logloss:0.37284
# [75]	validation_0-logloss:0.37283
# [76]	validation_0-logloss:0.37280
# [77]	validation_0-logloss:0.37276
# [78]	validation_0-logloss:0.37273
# [79]	validation_0-logloss:0.37272
# [80]	validation_0-logloss:0.37273
# [81]	validation_0-logloss:0.37269
# [82]	validation_0-logloss:0.37267
# [83]	validation_0-logloss:0.37265
# [84]	validation_0-logloss:0.37265
# [85]	validation_0-logloss:0.37264
# [86]	validation_0-logloss:0.37262
# [87]	validation_0-logloss:0.37262
# [88]	validation_0-logloss:0.37261
# [89]	validation_0-logloss:0.37260
# [90]	validation_0-logloss:0.37259
# [91]	validation_0-logloss:0.37259
# [92]	validation_0-logloss:0.37259
# [93]	validation_0-logloss:0.37258
# [94]	validation_0-logloss:0.37257
# [95]	validation_0-logloss:0.37257
# [96]	validation_0-logloss:0.37257
# [97]	validation_0-logloss:0.37256
# [98]	validation_0-logloss:0.37256
# [99]	validation_0-logloss:0.37255
# [0]	validation_0-logloss:0.64486
# [1]	validation_0-logloss:0.60539
# [2]	validation_0-logloss:0.57267
# [3]	validation_0-logloss:0.54522
# [4]	validation_0-logloss:0.52206
# [5]	validation_0-logloss:0.50233
# [6]	validation_0-logloss:0.48544
# [7]	validation_0-logloss:0.47094
# [8]	validation_0-logloss:0.45842
# [9]	validation_0-logloss:0.44759
# [10]	validation_0-logloss:0.43821
# [11]	validation_0-logloss:0.43004
# [12]	validation_0-logloss:0.42292
# [13]	validation_0-logloss:0.41672
# [14]	validation_0-logloss:0.41129
# [15]	validation_0-logloss:0.40655
# [16]	validation_0-logloss:0.40240
# [17]	validation_0-logloss:0.39875
# [18]	validation_0-logloss:0.39555
# [19]	validation_0-logloss:0.39276
# [20]	validation_0-logloss:0.39030
# [21]	validation_0-logloss:0.38814
# [22]	validation_0-logloss:0.38625
# [23]	validation_0-logloss:0.38457
# [24]	validation_0-logloss:0.38311
# [25]	validation_0-logloss:0.38182
# [26]	validation_0-logloss:0.38069
# [27]	validation_0-logloss:0.37968
# [28]	validation_0-logloss:0.37880
# [29]	validation_0-logloss:0.37803
# [30]	validation_0-logloss:0.37735
# [31]	validation_0-logloss:0.37676
# [32]	validation_0-logloss:0.37624
# [33]	validation_0-logloss:0.37578
# [34]	validation_0-logloss:0.37537
# [35]	validation_0-logloss:0.37502
# [36]	validation_0-logloss:0.37470
# [37]	validation_0-logloss:0.37443
# [38]	validation_0-logloss:0.37419
# [39]	validation_0-logloss:0.37398
# [40]	validation_0-logloss:0.37378
# [41]	validation_0-logloss:0.37362
# [42]	validation_0-logloss:0.37348
# [43]	validation_0-logloss:0.37335
# [44]	validation_0-logloss:0.37326
# [45]	validation_0-logloss:0.37315
# [46]	validation_0-logloss:0.37307
# [47]	validation_0-logloss:0.37299
# [48]	validation_0-logloss:0.37293
# [49]	validation_0-logloss:0.37288
# [50]	validation_0-logloss:0.37283
# [51]	validation_0-logloss:0.37278
# [52]	validation_0-logloss:0.37274
# [53]	validation_0-logloss:0.37271
# [54]	validation_0-logloss:0.37269
# [55]	validation_0-logloss:0.37266
# [56]	validation_0-logloss:0.37263
# [57]	validation_0-logloss:0.37262
# [58]	validation_0-logloss:0.37261
# [59]	validation_0-logloss:0.37259
# [60]	validation_0-logloss:0.37257
# [61]	validation_0-logloss:0.37257
# [62]	validation_0-logloss:0.37256
# [63]	validation_0-logloss:0.37255
# [64]	validation_0-logloss:0.37254
# [65]	validation_0-logloss:0.37254
# [66]	validation_0-logloss:0.37253
# [67]	validation_0-logloss:0.37252
# [68]	validation_0-logloss:0.37252
# [69]	validation_0-logloss:0.37252
# [0]	validation_0-logloss:0.51961
# [1]	validation_0-logloss:0.44369
# [2]	validation_0-logloss:0.39280
# [3]	validation_0-logloss:0.38037
# [4]	validation_0-logloss:0.37739
# [5]	validation_0-logloss:0.37545
# [6]	validation_0-logloss:0.37426
# [7]	validation_0-logloss:0.37337
# [8]	validation_0-logloss:0.37320
# [9]	validation_0-logloss:0.37288
# [10]	validation_0-logloss:0.37283
# [11]	validation_0-logloss:0.37277
# [12]	validation_0-logloss:0.37272
# [13]	validation_0-logloss:0.37271
# [14]	validation_0-logloss:0.37264
# [15]	validation_0-logloss:0.37264
# [16]	validation_0-logloss:0.37262
# [17]	validation_0-logloss:0.37259
# [18]	validation_0-logloss:0.37256
# [19]	validation_0-logloss:0.37255
# [20]	validation_0-logloss:0.37255
# [21]	validation_0-logloss:0.37251
# [22]	validation_0-logloss:0.37252
# [23]	validation_0-logloss:0.37249
# [24]	validation_0-logloss:0.37250
# [25]	validation_0-logloss:0.37247
# [26]	validation_0-logloss:0.37247
# [27]	validation_0-logloss:0.37247
# [28]	validation_0-logloss:0.37248
# [0]	validation_0-logloss:0.45993
# [1]	validation_0-logloss:0.39527
# [2]	validation_0-logloss:0.37912
# [3]	validation_0-logloss:0.37489
# [4]	validation_0-logloss:0.37307
# [5]	validation_0-logloss:0.37276
# [6]	validation_0-logloss:0.37261
# [7]	validation_0-logloss:0.37257
# [8]	validation_0-logloss:0.37257
# [9]	validation_0-logloss:0.37254
# [10]	validation_0-logloss:0.37253
# [11]	validation_0-logloss:0.37252
# [12]	validation_0-logloss:0.37252
# [13]	validation_0-logloss:0.37252
# [14]	validation_0-logloss:0.37251
# [15]	validation_0-logloss:0.37250
# [16]	validation_0-logloss:0.37250
# [17]	validation_0-logloss:0.37250
# [0]	validation_0-logloss:0.41167
# [1]	validation_0-logloss:0.38220
# [2]	validation_0-logloss:0.37491
# [3]	validation_0-logloss:0.37301
# [4]	validation_0-logloss:0.37259
# [5]	validation_0-logloss:0.37250
# [6]	validation_0-logloss:0.37250
# [7]	validation_0-logloss:0.37250
# [8]	validation_0-logloss:0.37250
# [0]	validation_0-logloss:2.04228
# [1]	validation_0-logloss:24.98836
# [2]	validation_0-logloss:9.78272
# [0]	validation_0-logloss:1.79099
# [1]	validation_0-logloss:24.48259
# [2]	validation_0-logloss:18.34502
# [0]	validation_0-logloss:1.38967
# [1]	validation_0-logloss:21.12067
# [2]	validation_0-logloss:19.67666
# [0]	validation_0-logloss:8.00990
# [1]	validation_0-logloss:8.00990
# [2]	validation_0-logloss:8.00990
# [3]	validation_0-logloss:8.00990
# [0]	validation_0-logloss:7.07149
# [1]	validation_0-logloss:27.05975
# [2]	validation_0-logloss:27.05975
# [0]	validation_0-logloss:5.82160
# [1]	validation_0-logloss:21.91155
# [2]	validation_0-logloss:21.91155
# [3]	validation_0-logloss:21.91155
# [0]	validation_0-logloss:0.68994
# [1]	validation_0-logloss:0.68679
# [2]	validation_0-logloss:0.68371
# [3]	validation_0-logloss:0.68070
# [4]	validation_0-logloss:0.67769
# [5]	validation_0-logloss:0.67476
# [6]	validation_0-logloss:0.67192
# [7]	validation_0-logloss:0.66914
# [8]	validation_0-logloss:0.66636
# [9]	validation_0-logloss:0.66368
# [10]	validation_0-logloss:0.66105
# [11]	validation_0-logloss:0.65843
# [12]	validation_0-logloss:0.65590
# [13]	validation_0-logloss:0.65341
# [14]	validation_0-logloss:0.65093
# [15]	validation_0-logloss:0.64857
# [16]	validation_0-logloss:0.64622
# [17]	validation_0-logloss:0.64389
# [18]	validation_0-logloss:0.64164
# [19]	validation_0-logloss:0.63935
# [20]	validation_0-logloss:0.63719
# [21]	validation_0-logloss:0.63500
# [22]	validation_0-logloss:0.63288
# [23]	validation_0-logloss:0.63081
# [24]	validation_0-logloss:0.62878
# [25]	validation_0-logloss:0.62675
# [26]	validation_0-logloss:0.62473
# [27]	validation_0-logloss:0.62280
# [28]	validation_0-logloss:0.62091
# [29]	validation_0-logloss:0.61898
# [30]	validation_0-logloss:0.61717
# [31]	validation_0-logloss:0.61533
# [32]	validation_0-logloss:0.61354
# [33]	validation_0-logloss:0.61177
# [34]	validation_0-logloss:0.61004
# [35]	validation_0-logloss:0.60832
# [36]	validation_0-logloss:0.60605
# [37]	validation_0-logloss:0.60443
# [38]	validation_0-logloss:0.60276
# [39]	validation_0-logloss:0.60118
# [40]	validation_0-logloss:0.59903
# [41]	validation_0-logloss:0.59748
# [42]	validation_0-logloss:0.59595
# [43]	validation_0-logloss:0.59448
# [44]	validation_0-logloss:0.59296
# [45]	validation_0-logloss:0.59092
# [46]	validation_0-logloss:0.58967
# [47]	validation_0-logloss:0.58828
# [48]	validation_0-logloss:0.58685
# [49]	validation_0-logloss:0.58565
# [50]	validation_0-logloss:0.58374
# [51]	validation_0-logloss:0.58256
# [52]	validation_0-logloss:0.58123
# [53]	validation_0-logloss:0.57995
# [54]	validation_0-logloss:0.57827
# [55]	validation_0-logloss:0.57718
# [56]	validation_0-logloss:0.57594
# [57]	validation_0-logloss:0.57471
# [58]	validation_0-logloss:0.57309
# [59]	validation_0-logloss:0.57193
# [60]	validation_0-logloss:0.57076
# [61]	validation_0-logloss:0.56977
# [62]	validation_0-logloss:0.56864
# [63]	validation_0-logloss:0.56712
# [64]	validation_0-logloss:0.56618
# [65]	validation_0-logloss:0.56507
# [66]	validation_0-logloss:0.56403
# [67]	validation_0-logloss:0.56257
# [68]	validation_0-logloss:0.56152
# [69]	validation_0-logloss:0.56049
# [70]	validation_0-logloss:0.55963
# [71]	validation_0-logloss:0.55878
# [72]	validation_0-logloss:0.55732
# [73]	validation_0-logloss:0.55649
# [74]	validation_0-logloss:0.55551
# [75]	validation_0-logloss:0.55460
# [76]	validation_0-logloss:0.55382
# [77]	validation_0-logloss:0.55243
# [78]	validation_0-logloss:0.55150
# [79]	validation_0-logloss:0.55075
# [80]	validation_0-logloss:0.54991
# [81]	validation_0-logloss:0.54849
# [82]	validation_0-logloss:0.54777
# [83]	validation_0-logloss:0.54697
# [84]	validation_0-logloss:0.54626
# [85]	validation_0-logloss:0.54558
# [86]	validation_0-logloss:0.54480
# [87]	validation_0-logloss:0.54359
# [88]	validation_0-logloss:0.54294
# [89]	validation_0-logloss:0.54227
# [90]	validation_0-logloss:0.54166
# [91]	validation_0-logloss:0.54042
# [92]	validation_0-logloss:0.53978
# [93]	validation_0-logloss:0.53918
# [94]	validation_0-logloss:0.53856
# [95]	validation_0-logloss:0.53798
# [96]	validation_0-logloss:0.53672
# [97]	validation_0-logloss:0.53613
# [98]	validation_0-logloss:0.53556
# [99]	validation_0-logloss:0.53492
# [0]	validation_0-logloss:0.68890
# [1]	validation_0-logloss:0.68473
# [2]	validation_0-logloss:0.68061
# [3]	validation_0-logloss:0.67662
# [4]	validation_0-logloss:0.67267
# [5]	validation_0-logloss:0.66881
# [6]	validation_0-logloss:0.66498
# [7]	validation_0-logloss:0.66122
# [8]	validation_0-logloss:0.65753
# [9]	validation_0-logloss:0.65394
# [10]	validation_0-logloss:0.65038
# [11]	validation_0-logloss:0.64691
# [12]	validation_0-logloss:0.64347
# [13]	validation_0-logloss:0.64010
# [14]	validation_0-logloss:0.63679
# [15]	validation_0-logloss:0.63354
# [16]	validation_0-logloss:0.63035
# [17]	validation_0-logloss:0.62718
# [18]	validation_0-logloss:0.62411
# [19]	validation_0-logloss:0.62107
# [20]	validation_0-logloss:0.61809
# [21]	validation_0-logloss:0.61515
# [22]	validation_0-logloss:0.61226
# [23]	validation_0-logloss:0.60941
# [24]	validation_0-logloss:0.60664
# [25]	validation_0-logloss:0.60386
# [26]	validation_0-logloss:0.60117
# [27]	validation_0-logloss:0.59850
# [28]	validation_0-logloss:0.59589
# [29]	validation_0-logloss:0.59332
# [30]	validation_0-logloss:0.59077
# [31]	validation_0-logloss:0.58830
# [32]	validation_0-logloss:0.58583
# [33]	validation_0-logloss:0.58342
# [34]	validation_0-logloss:0.58103
# [35]	validation_0-logloss:0.57868
# [36]	validation_0-logloss:0.57638
# [37]	validation_0-logloss:0.57411
# [38]	validation_0-logloss:0.57188
# [39]	validation_0-logloss:0.56968
# [40]	validation_0-logloss:0.56751
# [41]	validation_0-logloss:0.56534
# [42]	validation_0-logloss:0.56320
# [43]	validation_0-logloss:0.56111
# [44]	validation_0-logloss:0.55903
# [45]	validation_0-logloss:0.55700
# [46]	validation_0-logloss:0.55500
# [47]	validation_0-logloss:0.55300
# [48]	validation_0-logloss:0.55106
# [49]	validation_0-logloss:0.54917
# [50]	validation_0-logloss:0.54730
# [51]	validation_0-logloss:0.54549
# [52]	validation_0-logloss:0.54367
# [53]	validation_0-logloss:0.54192
# [54]	validation_0-logloss:0.54021
# [55]	validation_0-logloss:0.53851
# [56]	validation_0-logloss:0.53684
# [57]	validation_0-logloss:0.53518
# [58]	validation_0-logloss:0.53351
# [59]	validation_0-logloss:0.53189
# [60]	validation_0-logloss:0.53031
# [61]	validation_0-logloss:0.52878
# [62]	validation_0-logloss:0.52724
# [63]	validation_0-logloss:0.52566
# [64]	validation_0-logloss:0.52417
# [65]	validation_0-logloss:0.52269
# [66]	validation_0-logloss:0.52123
# [67]	validation_0-logloss:0.51979
# [68]	validation_0-logloss:0.51827
# [69]	validation_0-logloss:0.51687
# [70]	validation_0-logloss:0.51539
# [71]	validation_0-logloss:0.51402
# [72]	validation_0-logloss:0.51271
# [73]	validation_0-logloss:0.51128
# [74]	validation_0-logloss:0.50987
# [75]	validation_0-logloss:0.50859
# [76]	validation_0-logloss:0.50704
# [77]	validation_0-logloss:0.50561
# [78]	validation_0-logloss:0.50419
# [79]	validation_0-logloss:0.50246
# [80]	validation_0-logloss:0.50101
# [81]	validation_0-logloss:0.49947
# [82]	validation_0-logloss:0.49814
# [83]	validation_0-logloss:0.49664
# [84]	validation_0-logloss:0.49534
# [85]	validation_0-logloss:0.49389
# [86]	validation_0-logloss:0.49247
# [87]	validation_0-logloss:0.49134
# [88]	validation_0-logloss:0.48994
# [89]	validation_0-logloss:0.48874
# [90]	validation_0-logloss:0.48739
# [91]	validation_0-logloss:0.48632
# [92]	validation_0-logloss:0.48499
# [93]	validation_0-logloss:0.48386
# [94]	validation_0-logloss:0.48253
# [95]	validation_0-logloss:0.48125
# [96]	validation_0-logloss:0.48015
# [97]	validation_0-logloss:0.47877
# [98]	validation_0-logloss:0.47772
# [99]	validation_0-logloss:0.47651
# [0]	validation_0-logloss:0.68809
# [1]	validation_0-logloss:0.68314
# [2]	validation_0-logloss:0.67828
# [3]	validation_0-logloss:0.67353
# [4]	validation_0-logloss:0.66884
# [5]	validation_0-logloss:0.66428
# [6]	validation_0-logloss:0.65978
# [7]	validation_0-logloss:0.65537
# [8]	validation_0-logloss:0.65105
# [9]	validation_0-logloss:0.64682
# [10]	validation_0-logloss:0.64265
# [11]	validation_0-logloss:0.63856
# [12]	validation_0-logloss:0.63455
# [13]	validation_0-logloss:0.63059
# [14]	validation_0-logloss:0.62674
# [15]	validation_0-logloss:0.62293
# [16]	validation_0-logloss:0.61921
# [17]	validation_0-logloss:0.61554
# [18]	validation_0-logloss:0.61194
# [19]	validation_0-logloss:0.60840
# [20]	validation_0-logloss:0.60492
# [21]	validation_0-logloss:0.60151
# [22]	validation_0-logloss:0.59817
# [23]	validation_0-logloss:0.59486
# [24]	validation_0-logloss:0.59161
# [25]	validation_0-logloss:0.58843
# [26]	validation_0-logloss:0.58530
# [27]	validation_0-logloss:0.58221
# [28]	validation_0-logloss:0.57918
# [29]	validation_0-logloss:0.57621
# [30]	validation_0-logloss:0.57329
# [31]	validation_0-logloss:0.57040
# [32]	validation_0-logloss:0.56756
# [33]	validation_0-logloss:0.56478
# [34]	validation_0-logloss:0.56203
# [35]	validation_0-logloss:0.55934
# [36]	validation_0-logloss:0.55670
# [37]	validation_0-logloss:0.55409
# [38]	validation_0-logloss:0.55151
# [39]	validation_0-logloss:0.54900
# [40]	validation_0-logloss:0.54651
# [41]	validation_0-logloss:0.54406
# [42]	validation_0-logloss:0.54164
# [43]	validation_0-logloss:0.53927
# [44]	validation_0-logloss:0.53694
# [45]	validation_0-logloss:0.53465
# [46]	validation_0-logloss:0.53238
# [47]	validation_0-logloss:0.53017
# [48]	validation_0-logloss:0.52799
# [49]	validation_0-logloss:0.52581
# [50]	validation_0-logloss:0.52369
# [51]	validation_0-logloss:0.52160
# [52]	validation_0-logloss:0.51955
# [53]	validation_0-logloss:0.51751
# [54]	validation_0-logloss:0.51552
# [55]	validation_0-logloss:0.51356
# [56]	validation_0-logloss:0.51162
# [57]	validation_0-logloss:0.50971
# [58]	validation_0-logloss:0.50783
# [59]	validation_0-logloss:0.50599
# [60]	validation_0-logloss:0.50415
# [61]	validation_0-logloss:0.50235
# [62]	validation_0-logloss:0.50060
# [63]	validation_0-logloss:0.49885
# [64]	validation_0-logloss:0.49713
# [65]	validation_0-logloss:0.49544
# [66]	validation_0-logloss:0.49377
# [67]	validation_0-logloss:0.49213
# [68]	validation_0-logloss:0.49051
# [69]	validation_0-logloss:0.48893
# [70]	validation_0-logloss:0.48734
# [71]	validation_0-logloss:0.48580
# [72]	validation_0-logloss:0.48427
# [73]	validation_0-logloss:0.48276
# [74]	validation_0-logloss:0.48129
# [75]	validation_0-logloss:0.47983
# [76]	validation_0-logloss:0.47838
# [77]	validation_0-logloss:0.47696
# [78]	validation_0-logloss:0.47556
# [79]	validation_0-logloss:0.47420
# [80]	validation_0-logloss:0.47283
# [81]	validation_0-logloss:0.47150
# [82]	validation_0-logloss:0.47016
# [83]	validation_0-logloss:0.46887
# [84]	validation_0-logloss:0.46759
# [85]	validation_0-logloss:0.46632
# [86]	validation_0-logloss:0.46508
# [87]	validation_0-logloss:0.46384
# [88]	validation_0-logloss:0.46263
# [89]	validation_0-logloss:0.46144
# [90]	validation_0-logloss:0.46026
# [91]	validation_0-logloss:0.45910
# [92]	validation_0-logloss:0.45795
# [93]	validation_0-logloss:0.45682
# [94]	validation_0-logloss:0.45571
# [95]	validation_0-logloss:0.45460
# [96]	validation_0-logloss:0.45353
# [97]	validation_0-logloss:0.45245
# [98]	validation_0-logloss:0.45140
# [99]	validation_0-logloss:0.45036
# [0]	validation_0-logloss:0.66244
# [1]	validation_0-logloss:0.63742
# [2]	validation_0-logloss:0.61679
# [3]	validation_0-logloss:0.59914
# [4]	validation_0-logloss:0.57878
# [5]	validation_0-logloss:0.56764
# [6]	validation_0-logloss:0.55652
# [7]	validation_0-logloss:0.54721
# [8]	validation_0-logloss:0.54045
# [9]	validation_0-logloss:0.52862
# [10]	validation_0-logloss:0.51634
# [11]	validation_0-logloss:0.50399
# [12]	validation_0-logloss:0.50000
# [13]	validation_0-logloss:0.49115
# [14]	validation_0-logloss:0.48793
# [15]	validation_0-logloss:0.47866
# [16]	validation_0-logloss:0.47099
# [17]	validation_0-logloss:0.46729
# [18]	validation_0-logloss:0.46513
# [19]	validation_0-logloss:0.45915
# [20]	validation_0-logloss:0.45575
# [21]	validation_0-logloss:0.45072
# [22]	validation_0-logloss:0.44591
# [23]	validation_0-logloss:0.44172
# [24]	validation_0-logloss:0.43869
# [25]	validation_0-logloss:0.43487
# [26]	validation_0-logloss:0.43167
# [27]	validation_0-logloss:0.43078
# [28]	validation_0-logloss:0.42757
# [29]	validation_0-logloss:0.42484
# [30]	validation_0-logloss:0.42292
# [31]	validation_0-logloss:0.42137
# [32]	validation_0-logloss:0.41916
# [33]	validation_0-logloss:0.41392
# [34]	validation_0-logloss:0.41345
# [35]	validation_0-logloss:0.41297
# [36]	validation_0-logloss:0.41262
# [37]	validation_0-logloss:0.40812
# [38]	validation_0-logloss:0.40784
# [39]	validation_0-logloss:0.40750
# [40]	validation_0-logloss:0.40730
# [41]	validation_0-logloss:0.40534
# [42]	validation_0-logloss:0.40375
# [43]	validation_0-logloss:0.40021
# [44]	validation_0-logloss:0.39888
# [45]	validation_0-logloss:0.39868
# [46]	validation_0-logloss:0.39802
# [47]	validation_0-logloss:0.39747
# [48]	validation_0-logloss:0.39652
# [49]	validation_0-logloss:0.39382
# [50]	validation_0-logloss:0.39291
# [51]	validation_0-logloss:0.39279
# [52]	validation_0-logloss:0.39182
# [53]	validation_0-logloss:0.38970
# [54]	validation_0-logloss:0.38906
# [55]	validation_0-logloss:0.38895
# [56]	validation_0-logloss:0.38860
# [57]	validation_0-logloss:0.38771
# [58]	validation_0-logloss:0.38714
# [59]	validation_0-logloss:0.38703
# [60]	validation_0-logloss:0.38678
# [61]	validation_0-logloss:0.38673
# [62]	validation_0-logloss:0.38584
# [63]	validation_0-logloss:0.38574
# [64]	validation_0-logloss:0.38515
# [65]	validation_0-logloss:0.38498
# [66]	validation_0-logloss:0.38429
# [67]	validation_0-logloss:0.38425
# [68]	validation_0-logloss:0.38378
# [69]	validation_0-logloss:0.38375
# [70]	validation_0-logloss:0.38276
# [71]	validation_0-logloss:0.38234
# [72]	validation_0-logloss:0.38223
# [73]	validation_0-logloss:0.38172
# [74]	validation_0-logloss:0.38138
# [75]	validation_0-logloss:0.38092
# [76]	validation_0-logloss:0.38061
# [77]	validation_0-logloss:0.38037
# [78]	validation_0-logloss:0.38035
# [79]	validation_0-logloss:0.38010
# [80]	validation_0-logloss:0.37972
# [81]	validation_0-logloss:0.37966
# [82]	validation_0-logloss:0.37963
# [83]	validation_0-logloss:0.37925
# [84]	validation_0-logloss:0.37906
# [85]	validation_0-logloss:0.37890
# [86]	validation_0-logloss:0.37859
# [87]	validation_0-logloss:0.37842
# [88]	validation_0-logloss:0.37839
# [89]	validation_0-logloss:0.37828
# [90]	validation_0-logloss:0.37826
# [91]	validation_0-logloss:0.37808
# [92]	validation_0-logloss:0.37780
# [93]	validation_0-logloss:0.37759
# [94]	validation_0-logloss:0.37757
# [95]	validation_0-logloss:0.37756
# [96]	validation_0-logloss:0.37744
# [97]	validation_0-logloss:0.37732
# [98]	validation_0-logloss:0.37710
# [99]	validation_0-logloss:0.37694
# [0]	validation_0-logloss:0.65248
# [1]	validation_0-logloss:0.61872
# [2]	validation_0-logloss:0.59062
# [3]	validation_0-logloss:0.56682
# [4]	validation_0-logloss:0.54661
# [5]	validation_0-logloss:0.52884
# [6]	validation_0-logloss:0.51396
# [7]	validation_0-logloss:0.50020
# [8]	validation_0-logloss:0.48676
# [9]	validation_0-logloss:0.47641
# [10]	validation_0-logloss:0.46492
# [11]	validation_0-logloss:0.45499
# [12]	validation_0-logloss:0.44737
# [13]	validation_0-logloss:0.44038
# [14]	validation_0-logloss:0.43200
# [15]	validation_0-logloss:0.42568
# [16]	validation_0-logloss:0.41923
# [17]	validation_0-logloss:0.41484
# [18]	validation_0-logloss:0.41071
# [19]	validation_0-logloss:0.40758
# [20]	validation_0-logloss:0.40460
# [21]	validation_0-logloss:0.40214
# [22]	validation_0-logloss:0.39956
# [23]	validation_0-logloss:0.39805
# [24]	validation_0-logloss:0.39592
# [25]	validation_0-logloss:0.39460
# [26]	validation_0-logloss:0.39294
# [27]	validation_0-logloss:0.39199
# [28]	validation_0-logloss:0.39121
# [29]	validation_0-logloss:0.38959
# [30]	validation_0-logloss:0.38913
# [31]	validation_0-logloss:0.38851
# [32]	validation_0-logloss:0.38758
# [33]	validation_0-logloss:0.38672
# [34]	validation_0-logloss:0.38555
# [35]	validation_0-logloss:0.38501
# [36]	validation_0-logloss:0.38424
# [37]	validation_0-logloss:0.38376
# [38]	validation_0-logloss:0.38327
# [39]	validation_0-logloss:0.38194
# [40]	validation_0-logloss:0.38099
# [41]	validation_0-logloss:0.38001
# [42]	validation_0-logloss:0.37931
# [43]	validation_0-logloss:0.37857
# [44]	validation_0-logloss:0.37815
# [45]	validation_0-logloss:0.37778
# [46]	validation_0-logloss:0.37733
# [47]	validation_0-logloss:0.37684
# [48]	validation_0-logloss:0.37651
# [49]	validation_0-logloss:0.37613
# [50]	validation_0-logloss:0.37588
# [51]	validation_0-logloss:0.37571
# [52]	validation_0-logloss:0.37556
# [53]	validation_0-logloss:0.37524
# [54]	validation_0-logloss:0.37502
# [55]	validation_0-logloss:0.37478
# [56]	validation_0-logloss:0.37465
# [57]	validation_0-logloss:0.37454
# [58]	validation_0-logloss:0.37434
# [59]	validation_0-logloss:0.37425
# [60]	validation_0-logloss:0.37415
# [61]	validation_0-logloss:0.37404
# [62]	validation_0-logloss:0.37396
# [63]	validation_0-logloss:0.37389
# [64]	validation_0-logloss:0.37383
# [65]	validation_0-logloss:0.37376
# [66]	validation_0-logloss:0.37366
# [67]	validation_0-logloss:0.37360
# [68]	validation_0-logloss:0.37356
# [69]	validation_0-logloss:0.37353
# [70]	validation_0-logloss:0.37347
# [71]	validation_0-logloss:0.37344
# [72]	validation_0-logloss:0.37337
# [73]	validation_0-logloss:0.37334
# [74]	validation_0-logloss:0.37331
# [75]	validation_0-logloss:0.37329
# [76]	validation_0-logloss:0.37325
# [77]	validation_0-logloss:0.37322
# [78]	validation_0-logloss:0.37319
# [79]	validation_0-logloss:0.37318
# [80]	validation_0-logloss:0.37317
# [81]	validation_0-logloss:0.37316
# [82]	validation_0-logloss:0.37314
# [83]	validation_0-logloss:0.37313
# [84]	validation_0-logloss:0.37312
# [85]	validation_0-logloss:0.37311
# [86]	validation_0-logloss:0.37311
# [87]	validation_0-logloss:0.37310
# [88]	validation_0-logloss:0.37310
# [89]	validation_0-logloss:0.37308
# [90]	validation_0-logloss:0.37306
# [91]	validation_0-logloss:0.37306
# [92]	validation_0-logloss:0.37305
# [93]	validation_0-logloss:0.37305
# [94]	validation_0-logloss:0.37306
# [95]	validation_0-logloss:0.37305
# [96]	validation_0-logloss:0.37305
# [97]	validation_0-logloss:0.37302
# [98]	validation_0-logloss:0.37302
# [99]	validation_0-logloss:0.37301
# [0]	validation_0-logloss:0.64491
# [1]	validation_0-logloss:0.60545
# [2]	validation_0-logloss:0.57275
# [3]	validation_0-logloss:0.54531
# [4]	validation_0-logloss:0.52213
# [5]	validation_0-logloss:0.50237
# [6]	validation_0-logloss:0.48547
# [7]	validation_0-logloss:0.47095
# [8]	validation_0-logloss:0.45840
# [9]	validation_0-logloss:0.44756
# [10]	validation_0-logloss:0.43813
# [11]	validation_0-logloss:0.42996
# [12]	validation_0-logloss:0.42282
# [13]	validation_0-logloss:0.41659
# [14]	validation_0-logloss:0.41115
# [15]	validation_0-logloss:0.40640
# [16]	validation_0-logloss:0.40224
# [17]	validation_0-logloss:0.39859
# [18]	validation_0-logloss:0.39539
# [19]	validation_0-logloss:0.39260
# [20]	validation_0-logloss:0.39014
# [21]	validation_0-logloss:0.38797
# [22]	validation_0-logloss:0.38609
# [23]	validation_0-logloss:0.38443
# [24]	validation_0-logloss:0.38297
# [25]	validation_0-logloss:0.38170
# [26]	validation_0-logloss:0.38057
# [27]	validation_0-logloss:0.37959
# [28]	validation_0-logloss:0.37874
# [29]	validation_0-logloss:0.37799
# [30]	validation_0-logloss:0.37732
# [31]	validation_0-logloss:0.37674
# [32]	validation_0-logloss:0.37624
# [33]	validation_0-logloss:0.37579
# [34]	validation_0-logloss:0.37542
# [35]	validation_0-logloss:0.37508
# [36]	validation_0-logloss:0.37479
# [37]	validation_0-logloss:0.37453
# [38]	validation_0-logloss:0.37431
# [39]	validation_0-logloss:0.37412
# [40]	validation_0-logloss:0.37396
# [41]	validation_0-logloss:0.37381
# [42]	validation_0-logloss:0.37369
# [43]	validation_0-logloss:0.37358
# [44]	validation_0-logloss:0.37349
# [45]	validation_0-logloss:0.37341
# [46]	validation_0-logloss:0.37334
# [47]	validation_0-logloss:0.37328
# [48]	validation_0-logloss:0.37323
# [49]	validation_0-logloss:0.37320
# [50]	validation_0-logloss:0.37315
# [51]	validation_0-logloss:0.37312
# [52]	validation_0-logloss:0.37310
# [53]	validation_0-logloss:0.37308
# [54]	validation_0-logloss:0.37306
# [55]	validation_0-logloss:0.37305
# [56]	validation_0-logloss:0.37303
# [57]	validation_0-logloss:0.37302
# [58]	validation_0-logloss:0.37301
# [59]	validation_0-logloss:0.37300
# [60]	validation_0-logloss:0.37300
# [61]	validation_0-logloss:0.37299
# [62]	validation_0-logloss:0.37299
# [63]	validation_0-logloss:0.37300
# [64]	validation_0-logloss:0.37299
# [0]	validation_0-logloss:0.51885
# [1]	validation_0-logloss:0.44332
# [2]	validation_0-logloss:0.39377
# [3]	validation_0-logloss:0.38046
# [4]	validation_0-logloss:0.37753
# [5]	validation_0-logloss:0.37541
# [6]	validation_0-logloss:0.37410
# [7]	validation_0-logloss:0.37351
# [8]	validation_0-logloss:0.37330
# [9]	validation_0-logloss:0.37313
# [10]	validation_0-logloss:0.37312
# [11]	validation_0-logloss:0.37311
# [12]	validation_0-logloss:0.37310
# [13]	validation_0-logloss:0.37310
# [14]	validation_0-logloss:0.37313
# [15]	validation_0-logloss:0.37310
# [0]	validation_0-logloss:0.45881
# [1]	validation_0-logloss:0.39427
# [2]	validation_0-logloss:0.37882
# [3]	validation_0-logloss:0.37440
# [4]	validation_0-logloss:0.37334
# [5]	validation_0-logloss:0.37306
# [6]	validation_0-logloss:0.37296
# [7]	validation_0-logloss:0.37304
# [8]	validation_0-logloss:0.37299
# [9]	validation_0-logloss:0.37296
# [0]	validation_0-logloss:0.41115
# [1]	validation_0-logloss:0.38179
# [2]	validation_0-logloss:0.37488
# [3]	validation_0-logloss:0.37332
# [4]	validation_0-logloss:0.37303
# [5]	validation_0-logloss:0.37299
# [6]	validation_0-logloss:0.37299
# [7]	validation_0-logloss:0.37298
# [8]	validation_0-logloss:0.37298
# [9]	validation_0-logloss:0.37298
# [0]	validation_0-logloss:2.02710
# [1]	validation_0-logloss:24.49537
# [2]	validation_0-logloss:26.54394
# [0]	validation_0-logloss:1.78394
# [1]	validation_0-logloss:24.24451
# [2]	validation_0-logloss:18.43394
# [0]	validation_0-logloss:1.37338
# [1]	validation_0-logloss:26.56081
# [2]	validation_0-logloss:20.57679
# [0]	validation_0-logloss:7.92055
# [1]	validation_0-logloss:7.92055
# [2]	validation_0-logloss:7.92055
# [3]	validation_0-logloss:7.92055
# [0]	validation_0-logloss:7.02311
# [1]	validation_0-logloss:27.05920
# [2]	validation_0-logloss:27.05920
# [3]	validation_0-logloss:27.05920
# [0]	validation_0-logloss:5.77322
# [1]	validation_0-logloss:21.22901
# [2]	validation_0-logloss:9.78327
# [3]	validation_0-logloss:9.78327
# [0]	validation_0-logloss:0.68988
# [1]	validation_0-logloss:0.68677
# [2]	validation_0-logloss:0.68368
# [3]	validation_0-logloss:0.68063
# [4]	validation_0-logloss:0.67763
# [5]	validation_0-logloss:0.67468
# [6]	validation_0-logloss:0.67183
# [7]	validation_0-logloss:0.66904
# [8]	validation_0-logloss:0.66625
# [9]	validation_0-logloss:0.66360
# [10]	validation_0-logloss:0.66089
# [11]	validation_0-logloss:0.65832
# [12]	validation_0-logloss:0.65574
# [13]	validation_0-logloss:0.65324
# [14]	validation_0-logloss:0.65081
# [15]	validation_0-logloss:0.64838
# [16]	validation_0-logloss:0.64601
# [17]	validation_0-logloss:0.64368
# [18]	validation_0-logloss:0.64140
# [19]	validation_0-logloss:0.63919
# [20]	validation_0-logloss:0.63696
# [21]	validation_0-logloss:0.63480
# [22]	validation_0-logloss:0.63267
# [23]	validation_0-logloss:0.63059
# [24]	validation_0-logloss:0.62851
# [25]	validation_0-logloss:0.62651
# [26]	validation_0-logloss:0.62454
# [27]	validation_0-logloss:0.62259
# [28]	validation_0-logloss:0.62067
# [29]	validation_0-logloss:0.61877
# [30]	validation_0-logloss:0.61693
# [31]	validation_0-logloss:0.61508
# [32]	validation_0-logloss:0.61330
# [33]	validation_0-logloss:0.61152
# [34]	validation_0-logloss:0.60979
# [35]	validation_0-logloss:0.60806
# [36]	validation_0-logloss:0.60639
# [37]	validation_0-logloss:0.60414
# [38]	validation_0-logloss:0.60251
# [39]	validation_0-logloss:0.60091
# [40]	validation_0-logloss:0.59933
# [41]	validation_0-logloss:0.59779
# [42]	validation_0-logloss:0.59584
# [43]	validation_0-logloss:0.59435
# [44]	validation_0-logloss:0.59307
# [45]	validation_0-logloss:0.59157
# [46]	validation_0-logloss:0.58957
# [47]	validation_0-logloss:0.58831
# [48]	validation_0-logloss:0.58693
# [49]	validation_0-logloss:0.58571
# [50]	validation_0-logloss:0.58379
# [51]	validation_0-logloss:0.58262
# [52]	validation_0-logloss:0.58131
# [53]	validation_0-logloss:0.58001
# [54]	validation_0-logloss:0.57889
# [55]	validation_0-logloss:0.57708
# [56]	validation_0-logloss:0.57585
# [57]	validation_0-logloss:0.57479
# [58]	validation_0-logloss:0.57376
# [59]	validation_0-logloss:0.57200
# [60]	validation_0-logloss:0.57083
# [61]	validation_0-logloss:0.56985
# [62]	validation_0-logloss:0.56872
# [63]	validation_0-logloss:0.56774
# [64]	validation_0-logloss:0.56610
# [65]	validation_0-logloss:0.56501
# [66]	validation_0-logloss:0.56409
# [67]	validation_0-logloss:0.56303
# [68]	validation_0-logloss:0.56200
# [69]	validation_0-logloss:0.56058
# [70]	validation_0-logloss:0.55972
# [71]	validation_0-logloss:0.55873
# [72]	validation_0-logloss:0.55791
# [73]	validation_0-logloss:0.55637
# [74]	validation_0-logloss:0.55541
# [75]	validation_0-logloss:0.55463
# [76]	validation_0-logloss:0.55368
# [77]	validation_0-logloss:0.55279
# [78]	validation_0-logloss:0.55149
# [79]	validation_0-logloss:0.55075
# [80]	validation_0-logloss:0.55000
# [81]	validation_0-logloss:0.54926
# [82]	validation_0-logloss:0.54853
# [83]	validation_0-logloss:0.54729
# [84]	validation_0-logloss:0.54647
# [85]	validation_0-logloss:0.54577
# [86]	validation_0-logloss:0.54498
# [87]	validation_0-logloss:0.54429
# [88]	validation_0-logloss:0.54310
# [89]	validation_0-logloss:0.54245
# [90]	validation_0-logloss:0.54184
# [91]	validation_0-logloss:0.54119
# [92]	validation_0-logloss:0.54007
# [93]	validation_0-logloss:0.53934
# [94]	validation_0-logloss:0.53873
# [95]	validation_0-logloss:0.53814
# [96]	validation_0-logloss:0.53756
# [97]	validation_0-logloss:0.53648
# [98]	validation_0-logloss:0.53590
# [99]	validation_0-logloss:0.53537
# [0]	validation_0-logloss:0.68885
# [1]	validation_0-logloss:0.68465
# [2]	validation_0-logloss:0.68052
# [3]	validation_0-logloss:0.67649
# [4]	validation_0-logloss:0.67251
# [5]	validation_0-logloss:0.66862
# [6]	validation_0-logloss:0.66478
# [7]	validation_0-logloss:0.66103
# [8]	validation_0-logloss:0.65731
# [9]	validation_0-logloss:0.65370
# [10]	validation_0-logloss:0.65012
# [11]	validation_0-logloss:0.64662
# [12]	validation_0-logloss:0.64316
# [13]	validation_0-logloss:0.63977
# [14]	validation_0-logloss:0.63643
# [15]	validation_0-logloss:0.63318
# [16]	validation_0-logloss:0.62994
# [17]	validation_0-logloss:0.62677
# [18]	validation_0-logloss:0.62369
# [19]	validation_0-logloss:0.62062
# [20]	validation_0-logloss:0.61762
# [21]	validation_0-logloss:0.61466
# [22]	validation_0-logloss:0.61176
# [23]	validation_0-logloss:0.60889
# [24]	validation_0-logloss:0.60610
# [25]	validation_0-logloss:0.60332
# [26]	validation_0-logloss:0.60061
# [27]	validation_0-logloss:0.59792
# [28]	validation_0-logloss:0.59529
# [29]	validation_0-logloss:0.59270
# [30]	validation_0-logloss:0.59015
# [31]	validation_0-logloss:0.58765
# [32]	validation_0-logloss:0.58517
# [33]	validation_0-logloss:0.58275
# [34]	validation_0-logloss:0.58035
# [35]	validation_0-logloss:0.57800
# [36]	validation_0-logloss:0.57568
# [37]	validation_0-logloss:0.57339
# [38]	validation_0-logloss:0.57112
# [39]	validation_0-logloss:0.56886
# [40]	validation_0-logloss:0.56667
# [41]	validation_0-logloss:0.56447
# [42]	validation_0-logloss:0.56236
# [43]	validation_0-logloss:0.56024
# [44]	validation_0-logloss:0.55817
# [45]	validation_0-logloss:0.55611
# [46]	validation_0-logloss:0.55411
# [47]	validation_0-logloss:0.55214
# [48]	validation_0-logloss:0.55027
# [49]	validation_0-logloss:0.54842
# ...
# [75]	validation_0-logloss:0.50741
# [76]	validation_0-logloss:0.50597
# [77]	validation_0-logloss:0.50467
# [78]	validation_0-logloss:0.50329
# [79]	validation_0-logloss:0.50205
# [80]	validation_0-logloss:0.50058
# [81]	validation_0-logloss:0.49924
# [82]	validation_0-logloss:0.49757
# [83]	validation_0-logloss:0.49616
# [84]	validation_0-logloss:0.49497
# [85]	validation_0-logloss:0.49358
# [86]	validation_0-logloss:0.49230
# [87]	validation_0-logloss:0.49096
# [88]	validation_0-logloss:0.48970
# [89]	validation_0-logloss:0.48848
# [90]	validation_0-logloss:0.48711
# [91]	validation_0-logloss:0.48575
# [92]	validation_0-logloss:0.48456
# [93]	validation_0-logloss:0.48325
# [94]	validation_0-logloss:0.48229
# [95]	validation_0-logloss:0.48097
# [96]	validation_0-logloss:0.47987
# [97]	validation_0-logloss:0.47862
# [98]	validation_0-logloss:0.47754
# [99]	validation_0-logloss:0.47644
# [0]	validation_0-logloss:0.68808
# [1]	validation_0-logloss:0.68311
# [2]	validation_0-logloss:0.67822
# [3]	validation_0-logloss:0.67344
# [4]	validation_0-logloss:0.66875
# [5]	validation_0-logloss:0.66416
# [6]	validation_0-logloss:0.65965
# [7]	validation_0-logloss:0.65523
# [8]	validation_0-logloss:0.65088
# [9]	validation_0-logloss:0.64663
# [10]	validation_0-logloss:0.64243
# [11]	validation_0-logloss:0.63833
# [12]	validation_0-logloss:0.63431
# [13]	validation_0-logloss:0.63035
# [14]	validation_0-logloss:0.62647
# [15]	validation_0-logloss:0.62265
# [16]	validation_0-logloss:0.61890
# [17]	validation_0-logloss:0.61522
# [18]	validation_0-logloss:0.61160
# [19]	validation_0-logloss:0.60805
# [20]	validation_0-logloss:0.60456
# [21]	validation_0-logloss:0.60114
# [22]	validation_0-logloss:0.59776
# [23]	validation_0-logloss:0.59446
# [24]	validation_0-logloss:0.59118
# [25]	validation_0-logloss:0.58800
# [26]	validation_0-logloss:0.58486
# [27]	validation_0-logloss:0.58176
# [28]	validation_0-logloss:0.57872
# [29]	validation_0-logloss:0.57572
# [30]	validation_0-logloss:0.57279
# [31]	validation_0-logloss:0.56989
# [32]	validation_0-logloss:0.56705
# [33]	validation_0-logloss:0.56424
# [34]	validation_0-logloss:0.56150
# [35]	validation_0-logloss:0.55879
# [36]	validation_0-logloss:0.55612
# [37]	validation_0-logloss:0.55351
# [38]	validation_0-logloss:0.55093
# [39]	validation_0-logloss:0.54839
# [40]	validation_0-logloss:0.54590
# [41]	validation_0-logloss:0.54344
# [42]	validation_0-logloss:0.54102
# [43]	validation_0-logloss:0.53865
# [44]	validation_0-logloss:0.53630
# [45]	validation_0-logloss:0.53400
# [46]	validation_0-logloss:0.53172
# [47]	validation_0-logloss:0.52949
# [48]	validation_0-logloss:0.52729
# [49]	validation_0-logloss:0.52513
# [50]	validation_0-logloss:0.52299
# [51]	validation_0-logloss:0.52089
# [52]	validation_0-logloss:0.51882
# [53]	validation_0-logloss:0.51678
# [54]	validation_0-logloss:0.51479
# [55]	validation_0-logloss:0.51280
# [56]	validation_0-logloss:0.51087
# [57]	validation_0-logloss:0.50894
# [58]	validation_0-logloss:0.50705
# [59]	validation_0-logloss:0.50520
# [60]	validation_0-logloss:0.50337
# [61]	validation_0-logloss:0.50157
# [62]	validation_0-logloss:0.49978
# [63]	validation_0-logloss:0.49804
# [64]	validation_0-logloss:0.49632
# [65]	validation_0-logloss:0.49461
# [66]	validation_0-logloss:0.49294
# [67]	validation_0-logloss:0.49129
# [68]	validation_0-logloss:0.48966
# [69]	validation_0-logloss:0.48805
# [70]	validation_0-logloss:0.48649
# [71]	validation_0-logloss:0.48492
# [72]	validation_0-logloss:0.48339
# [73]	validation_0-logloss:0.48188
# [74]	validation_0-logloss:0.48039
# [75]	validation_0-logloss:0.47891
# [76]	validation_0-logloss:0.47746
# [77]	validation_0-logloss:0.47604
# [78]	validation_0-logloss:0.47465
# [79]	validation_0-logloss:0.47326
# [80]	validation_0-logloss:0.47188
# [81]	validation_0-logloss:0.47056
# [82]	validation_0-logloss:0.46921
# [83]	validation_0-logloss:0.46790
# [84]	validation_0-logloss:0.46662
# [85]	validation_0-logloss:0.46535
# [86]	validation_0-logloss:0.46410
# [87]	validation_0-logloss:0.46286
# [88]	validation_0-logloss:0.46165
# [89]	validation_0-logloss:0.46043
# [90]	validation_0-logloss:0.45926
# [91]	validation_0-logloss:0.45809
# [92]	validation_0-logloss:0.45694
# [93]	validation_0-logloss:0.45580
# [94]	validation_0-logloss:0.45468
# [95]	validation_0-logloss:0.45356
# [96]	validation_0-logloss:0.45249
# [97]	validation_0-logloss:0.45141
# [98]	validation_0-logloss:0.45035
# [99]	validation_0-logloss:0.44931
# [0]	validation_0-logloss:0.66240
# [1]	validation_0-logloss:0.63738
# [2]	validation_0-logloss:0.61675
# [3]	validation_0-logloss:0.59922
# [4]	validation_0-logloss:0.57878
# [5]	validation_0-logloss:0.56770
# [6]	validation_0-logloss:0.55663
# [7]	validation_0-logloss:0.54739
# [8]	validation_0-logloss:0.54071
# [9]	validation_0-logloss:0.52876
# [10]	validation_0-logloss:0.51648
# [11]	validation_0-logloss:0.50830
# [12]	validation_0-logloss:0.50449
# [13]	validation_0-logloss:0.49336
# [14]	validation_0-logloss:0.48440
# [15]	validation_0-logloss:0.47863
# [16]	validation_0-logloss:0.47626
# [17]	validation_0-logloss:0.46905
# [18]	validation_0-logloss:0.46097
# [19]	validation_0-logloss:0.45932
# [20]	validation_0-logloss:0.45248
# [21]	validation_0-logloss:0.44712
# [22]	validation_0-logloss:0.44256
# [23]	validation_0-logloss:0.44136
# [24]	validation_0-logloss:0.43750
# [25]	validation_0-logloss:0.43646
# [26]	validation_0-logloss:0.43541
# [27]	validation_0-logloss:0.43319
# [28]	validation_0-logloss:0.42798
# [29]	validation_0-logloss:0.42490
# [30]	validation_0-logloss:0.42429
# [31]	validation_0-logloss:0.42161
# [32]	validation_0-logloss:0.41908
# [33]	validation_0-logloss:0.41678
# [34]	validation_0-logloss:0.41513
# [35]	validation_0-logloss:0.41475
# [36]	validation_0-logloss:0.40976
# [37]	validation_0-logloss:0.40799
# [38]	validation_0-logloss:0.40771
# [39]	validation_0-logloss:0.40362
# [40]	validation_0-logloss:0.40336
# [41]	validation_0-logloss:0.40313
# [42]	validation_0-logloss:0.40184
# [43]	validation_0-logloss:0.40032
# [44]	validation_0-logloss:0.40004
# [45]	validation_0-logloss:0.39916
# [46]	validation_0-logloss:0.39891
# [47]	validation_0-logloss:0.39878
# [48]	validation_0-logloss:0.39794
# [49]	validation_0-logloss:0.39638
# [50]	validation_0-logloss:0.39609
# [51]	validation_0-logloss:0.39540
# [52]	validation_0-logloss:0.39353
# [53]	validation_0-logloss:0.39332
# [54]	validation_0-logloss:0.39238
# [55]	validation_0-logloss:0.39109
# [56]	validation_0-logloss:0.39030
# [57]	validation_0-logloss:0.38958
# [58]	validation_0-logloss:0.38890
# [59]	validation_0-logloss:0.38783
# [60]	validation_0-logloss:0.38748
# [61]	validation_0-logloss:0.38740
# [62]	validation_0-logloss:0.38734
# [63]	validation_0-logloss:0.38628
# [64]	validation_0-logloss:0.38573
# [65]	validation_0-logloss:0.38490
# [66]	validation_0-logloss:0.38442
# [67]	validation_0-logloss:0.38402
# [68]	validation_0-logloss:0.38397
# [69]	validation_0-logloss:0.38244
# [70]	validation_0-logloss:0.38239
# [71]	validation_0-logloss:0.38176
# [72]	validation_0-logloss:0.38116
# [73]	validation_0-logloss:0.38083
# [74]	validation_0-logloss:0.38079
# [75]	validation_0-logloss:0.38064
# [76]	validation_0-logloss:0.38061
# [77]	validation_0-logloss:0.38008
# [78]	validation_0-logloss:0.37982
# [79]	validation_0-logloss:0.37979
# [80]	validation_0-logloss:0.37874
# [81]	validation_0-logloss:0.37872
# [82]	validation_0-logloss:0.37833
# [83]	validation_0-logloss:0.37830
# [84]	validation_0-logloss:0.37809
# [85]	validation_0-logloss:0.37801
# [86]	validation_0-logloss:0.37763
# [87]	validation_0-logloss:0.37760
# [88]	validation_0-logloss:0.37749
# [89]	validation_0-logloss:0.37748
# [90]	validation_0-logloss:0.37671
# [91]	validation_0-logloss:0.37641
# [92]	validation_0-logloss:0.37640
# [93]	validation_0-logloss:0.37639
# [94]	validation_0-logloss:0.37638
# [95]	validation_0-logloss:0.37624
# [96]	validation_0-logloss:0.37598
# [97]	validation_0-logloss:0.37596
# [98]	validation_0-logloss:0.37593
# [99]	validation_0-logloss:0.37588
# [0]	validation_0-logloss:0.65239
# [1]	validation_0-logloss:0.61858
# [2]	validation_0-logloss:0.59054
# [3]	validation_0-logloss:0.56678
# [4]	validation_0-logloss:0.54613
# [5]	validation_0-logloss:0.52830
# [6]	validation_0-logloss:0.51346
# [7]	validation_0-logloss:0.50039
# [8]	validation_0-logloss:0.48539
# [9]	validation_0-logloss:0.47486
# [10]	validation_0-logloss:0.46320
# [11]	validation_0-logloss:0.45313
# [12]	validation_0-logloss:0.44567
# [13]	validation_0-logloss:0.43651
# [14]	validation_0-logloss:0.43025
# [15]	validation_0-logloss:0.42306
# [16]	validation_0-logloss:0.41678
# [17]	validation_0-logloss:0.41242
# [18]	validation_0-logloss:0.40842
# [19]	validation_0-logloss:0.40509
# [20]	validation_0-logloss:0.40183
# [21]	validation_0-logloss:0.39950
# [22]	validation_0-logloss:0.39610
# [23]	validation_0-logloss:0.39419
# [24]	validation_0-logloss:0.39144
# [25]	validation_0-logloss:0.38956
# [26]	validation_0-logloss:0.38830
# [27]	validation_0-logloss:0.38623
# [28]	validation_0-logloss:0.38486
# [29]	validation_0-logloss:0.38355
# [30]	validation_0-logloss:0.38261
# [31]	validation_0-logloss:0.38189
# [32]	validation_0-logloss:0.38086
# [33]	validation_0-logloss:0.38031
# [34]	validation_0-logloss:0.37916
# [35]	validation_0-logloss:0.37838
# [36]	validation_0-logloss:0.37790
# [37]	validation_0-logloss:0.37705
# [38]	validation_0-logloss:0.37664
# [39]	validation_0-logloss:0.37612
# [40]	validation_0-logloss:0.37550
# [41]	validation_0-logloss:0.37519
# [42]	validation_0-logloss:0.37489
# [43]	validation_0-logloss:0.37465
# [44]	validation_0-logloss:0.37421
# [45]	validation_0-logloss:0.37397
# [46]	validation_0-logloss:0.37372
# [47]	validation_0-logloss:0.37338
# [48]	validation_0-logloss:0.37323
# [49]	validation_0-logloss:0.37307
# [50]	validation_0-logloss:0.37294
# [51]	validation_0-logloss:0.37284
# [52]	validation_0-logloss:0.37271
# [53]	validation_0-logloss:0.37250
# [54]	validation_0-logloss:0.37236
# [55]	validation_0-logloss:0.37221
# [56]	validation_0-logloss:0.37211
# [57]	validation_0-logloss:0.37201
# [58]	validation_0-logloss:0.37196
# [59]	validation_0-logloss:0.37189
# [60]	validation_0-logloss:0.37176
# [61]	validation_0-logloss:0.37169
# [62]	validation_0-logloss:0.37164
# [63]	validation_0-logloss:0.37153
# [64]	validation_0-logloss:0.37146
# [65]	validation_0-logloss:0.37139
# [66]	validation_0-logloss:0.37134
# [67]	validation_0-logloss:0.37127
# [68]	validation_0-logloss:0.37122
# [69]	validation_0-logloss:0.37119
# [70]	validation_0-logloss:0.37117
# [71]	validation_0-logloss:0.37114
# [72]	validation_0-logloss:0.37113
# [73]	validation_0-logloss:0.37110
# [74]	validation_0-logloss:0.37108
# [75]	validation_0-logloss:0.37106
# [76]	validation_0-logloss:0.37103
# [77]	validation_0-logloss:0.37100
# [78]	validation_0-logloss:0.37099
# [79]	validation_0-logloss:0.37098
# [80]	validation_0-logloss:0.37096
# [81]	validation_0-logloss:0.37096
# [82]	validation_0-logloss:0.37093
# [83]	validation_0-logloss:0.37093
# [84]	validation_0-logloss:0.37091
# [85]	validation_0-logloss:0.37090
# [86]	validation_0-logloss:0.37088
# [87]	validation_0-logloss:0.37088
# [88]	validation_0-logloss:0.37087
# [89]	validation_0-logloss:0.37086
# [90]	validation_0-logloss:0.37086
# [91]	validation_0-logloss:0.37084
# [92]	validation_0-logloss:0.37084
# [93]	validation_0-logloss:0.37085
# [94]	validation_0-logloss:0.37084
# [95]	validation_0-logloss:0.37084
# [96]	validation_0-logloss:0.37084
# [97]	validation_0-logloss:0.37084
# [98]	validation_0-logloss:0.37083
# [99]	validation_0-logloss:0.37082
# [0]	validation_0-logloss:0.64470
# [1]	validation_0-logloss:0.60509
# [2]	validation_0-logloss:0.57225
# [3]	validation_0-logloss:0.54470
# [4]	validation_0-logloss:0.52142
# [5]	validation_0-logloss:0.50158
# [6]	validation_0-logloss:0.48460
# [7]	validation_0-logloss:0.46999
# [8]	validation_0-logloss:0.45741
# [9]	validation_0-logloss:0.44649
# [10]	validation_0-logloss:0.43702
# [11]	validation_0-logloss:0.42878
# [12]	validation_0-logloss:0.42160
# [13]	validation_0-logloss:0.41534
# [14]	validation_0-logloss:0.40987
# [15]	validation_0-logloss:0.40507
# [16]	validation_0-logloss:0.40087
# [17]	validation_0-logloss:0.39719
# [18]	validation_0-logloss:0.39397
# [19]	validation_0-logloss:0.39113
# [20]	validation_0-logloss:0.38864
# [21]	validation_0-logloss:0.38646
# [22]	validation_0-logloss:0.38454
# [23]	validation_0-logloss:0.38284
# [24]	validation_0-logloss:0.38137
# [25]	validation_0-logloss:0.38006
# [26]	validation_0-logloss:0.37892
# [27]	validation_0-logloss:0.37791
# [28]	validation_0-logloss:0.37703
# [29]	validation_0-logloss:0.37626
# [30]	validation_0-logloss:0.37557
# [31]	validation_0-logloss:0.37498
# [32]	validation_0-logloss:0.37445
# [33]	validation_0-logloss:0.37398
# [34]	validation_0-logloss:0.37358
# [35]	validation_0-logloss:0.37323
# [36]	validation_0-logloss:0.37292
# [37]	validation_0-logloss:0.37264
# [38]	validation_0-logloss:0.37241
# [39]	validation_0-logloss:0.37220
# [40]	validation_0-logloss:0.37202
# [41]	validation_0-logloss:0.37186
# [42]	validation_0-logloss:0.37173
# [43]	validation_0-logloss:0.37160
# [44]	validation_0-logloss:0.37150
# [45]	validation_0-logloss:0.37141
# [46]	validation_0-logloss:0.37133
# [47]	validation_0-logloss:0.37126
# [48]	validation_0-logloss:0.37120
# [49]	validation_0-logloss:0.37115
# [50]	validation_0-logloss:0.37110
# [51]	validation_0-logloss:0.37107
# [52]	validation_0-logloss:0.37104
# [53]	validation_0-logloss:0.37101
# [54]	validation_0-logloss:0.37098
# [55]	validation_0-logloss:0.37096
# [56]	validation_0-logloss:0.37094
# [57]	validation_0-logloss:0.37094
# [58]	validation_0-logloss:0.37091
# [59]	validation_0-logloss:0.37090
# [60]	validation_0-logloss:0.37089
# [61]	validation_0-logloss:0.37089
# [62]	validation_0-logloss:0.37087
# [63]	validation_0-logloss:0.37087
# [64]	validation_0-logloss:0.37087
# [65]	validation_0-logloss:0.37086
# [66]	validation_0-logloss:0.37086
# [67]	validation_0-logloss:0.37086
# [68]	validation_0-logloss:0.37086
# [69]	validation_0-logloss:0.37085
# [70]	validation_0-logloss:0.37084
# [71]	validation_0-logloss:0.37085
# [72]	validation_0-logloss:0.37084
# [73]	validation_0-logloss:0.37084
# [74]	validation_0-logloss:0.37084
# [75]	validation_0-logloss:0.37084
# [76]	validation_0-logloss:0.37084
# [77]	validation_0-logloss:0.37084
# [78]	validation_0-logloss:0.37084
# [79]	validation_0-logloss:0.37084
# [0]	validation_0-logloss:0.52021
# [1]	validation_0-logloss:0.44166
# [2]	validation_0-logloss:0.39045
# [3]	validation_0-logloss:0.37845
# [4]	validation_0-logloss:0.37551
# [5]	validation_0-logloss:0.37334
# [6]	validation_0-logloss:0.37241
# [7]	validation_0-logloss:0.37212
# [8]	validation_0-logloss:0.37134
# [9]	validation_0-logloss:0.37121
# [10]	validation_0-logloss:0.37103
# [11]	validation_0-logloss:0.37098
# [12]	validation_0-logloss:0.37097
# [13]	validation_0-logloss:0.37091
# [14]	validation_0-logloss:0.37092
# [15]	validation_0-logloss:0.37090
# [16]	validation_0-logloss:0.37087
# [17]	validation_0-logloss:0.37088
# [18]	validation_0-logloss:0.37090
# [19]	validation_0-logloss:0.37085
# [20]	validation_0-logloss:0.37083
# [21]	validation_0-logloss:0.37077
# [22]	validation_0-logloss:0.37078
# [23]	validation_0-logloss:0.37079
# [0]	validation_0-logloss:0.45895
# [1]	validation_0-logloss:0.39181
# [2]	validation_0-logloss:0.37669
# [3]	validation_0-logloss:0.37254
# [4]	validation_0-logloss:0.37128
# [5]	validation_0-logloss:0.37103
# [6]	validation_0-logloss:0.37087
# [7]	validation_0-logloss:0.37083
# [8]	validation_0-logloss:0.37078
# [9]	validation_0-logloss:0.37078
# [10]	validation_0-logloss:0.37078
# [11]	validation_0-logloss:0.37079
# [12]	validation_0-logloss:0.37080
# [0]	validation_0-logloss:0.41003
# [1]	validation_0-logloss:0.38023
# [2]	validation_0-logloss:0.37304
# [3]	validation_0-logloss:0.37127
# [4]	validation_0-logloss:0.37090
# [5]	validation_0-logloss:0.37084
# [6]	validation_0-logloss:0.37084
# [7]	validation_0-logloss:0.37084
# [8]	validation_0-logloss:0.37084
# [9]	validation_0-logloss:0.37084
# [0]	validation_0-logloss:2.06586
# [1]	validation_0-logloss:25.06517
# [2]	validation_0-logloss:9.78327
# [0]	validation_0-logloss:1.78887
# [1]	validation_0-logloss:24.24595
# [2]	validation_0-logloss:14.22072
# [0]	validation_0-logloss:1.36256
# [1]	validation_0-logloss:26.76938
# [2]	validation_0-logloss:23.69623
# [3]	validation_0-logloss:9.78327
# [0]	validation_0-logloss:8.02204
# [1]	validation_0-logloss:8.02204
# [2]	validation_0-logloss:8.02204
# [0]	validation_0-logloss:7.03206
# [1]	validation_0-logloss:27.05920
# [2]	validation_0-logloss:27.05920
# [0]	validation_0-logloss:5.81911
# [1]	validation_0-logloss:22.25174
# [2]	validation_0-logloss:22.25174
# [3]	validation_0-logloss:22.25174

# %%
# tuned hyperparameters

# with respect to the accuracy_score
cv = np.mean(acses, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'accuracy_score']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'accuracy_score']['max_depth'] = max_depths[depth_index]

# with respect to the precision
cv = np.mean(pres, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'precision']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'precision']['max_depth'] = max_depths[depth_index]

# with respect to the true_positive_rate
cv = np.mean(tprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'true_positive_rate']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'true_positive_rate']['max_depth'] = max_depths[depth_index]

# with respect to the false_positive_rate
cv = np.mean(fprs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'false_positive_rate']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'false_positive_rate']['max_depth'] = max_depths[depth_index]

# with respect to the f1
cv = np.mean(f1s, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'f1']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'f1']['max_depth'] = max_depths[depth_index]

# with respect to the roc_auc
cv = np.mean(aucs, axis = 0)
max_cv = np.max(np.max(cv, axis = 0),axis = 0)
rate_index = np.argwhere(cv == max_cv)[0][0]
depth_index = np.argwhere(cv == max_cv)[0][1]
paras.loc['XGB', 'roc_auc']['learning_rate'] = learning_rates[rate_index]
paras.loc['XGB', 'roc_auc']['max_depth'] = max_depths[depth_index]

# %%
paras
# Out:
#                             accuracy_score  \
# Base                                    {}
# Log           {'penalty': 'l2', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB   {'learning_rate': 1, 'max_depth': 3}
#
#                                      precision  \
# Base                                        {}
# Log       {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                         {}
# SVM                            {'margin': 0.1}
# DT        {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                            {'max_depth': 6}
# XGB   {'learning_rate': 0.01, 'max_depth': 10}
#
#                            true_positive_rate  \
# Base                                       {}
# Log      {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                        {}
# SVM                            {'margin': 10}
# DT       {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                           {'max_depth': 3}
# XGB   {'learning_rate': 0.01, 'max_depth': 3}
#
#                           false_positive_rate  \
# Base                                       {}
# Log      {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                        {}
# SVM                            {'margin': 10}
# DT       {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                           {'max_depth': 3}
# XGB   {'learning_rate': 0.01, 'max_depth': 3}
#
#                                           f1  \
# Base                                      {}
# Log     {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                       {}
# SVM                           {'margin': 10}
# DT      {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                          {'max_depth': 6}
# XGB   {'learning_rate': 0.1, 'max_depth': 3}
#
#                                     roc_auc
# Base                                     {}
# Log    {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                      {}
# SVM                         {'margin': 0.1}
# DT     {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                         {'max_depth': 6}
# XGB   {'learning_rate': 1, 'max_depth': 10}

# %%
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %% [markdown]
# ### -Tuned Hyperparameters and Selected Features-

# %%
#tuned hyperparameters
paras
# Out:
#                             accuracy_score  \
# Base                                    {}
# Log           {'penalty': 'l2', 'C': 0.01}
# LDA                                     {}
# SVM                         {'margin': 10}
# DT    {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                        {'max_depth': 6}
# XGB   {'learning_rate': 1, 'max_depth': 3}
#
#                                      precision  \
# Base                                        {}
# Log       {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                         {}
# SVM                            {'margin': 0.1}
# DT        {'max_depth': 7.0, 'ccp_alpha': 0.0}
# RF                            {'max_depth': 6}
# XGB   {'learning_rate': 0.01, 'max_depth': 10}
#
#                            true_positive_rate  \
# Base                                       {}
# Log      {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                        {}
# SVM                            {'margin': 10}
# DT       {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                           {'max_depth': 3}
# XGB   {'learning_rate': 0.01, 'max_depth': 3}
#
#                           false_positive_rate  \
# Base                                       {}
# Log      {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                        {}
# SVM                            {'margin': 10}
# DT       {'max_depth': 1.0, 'ccp_alpha': 0.0}
# RF                           {'max_depth': 3}
# XGB   {'learning_rate': 0.01, 'max_depth': 3}
#
#                                           f1  \
# Base                                      {}
# Log     {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                       {}
# SVM                           {'margin': 10}
# DT      {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                          {'max_depth': 6}
# XGB   {'learning_rate': 0.1, 'max_depth': 3}
#
#                                     roc_auc
# Base                                     {}
# Log    {'penalty': 'elasticnet', 'C': 0.01}
# LDA                                      {}
# SVM                         {'margin': 0.1}
# DT     {'max_depth': 8.0, 'ccp_alpha': 0.0}
# RF                         {'max_depth': 6}
# XGB   {'learning_rate': 1, 'max_depth': 10}

# %%
# selected features
feats
# Out:
#                                         accuracy_score  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                              precision  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [A, B, C, 417380, 417614, 417740, 999001, cont...
#
#                                     true_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                    false_positive_rate  \
# LDA                   [417380, 417614, 417740, 999001]
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                     f1  \
# LDA  [contraindication, 417380, 417614, 417740, 999...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...
#
#                                                roc_auc
# LDA  [correct_diagnosis, tried_and_failed, contrain...
# SVM  [417380, 417614, 417740, 999001, tried_and_fai...

# %% [markdown]
# # 2. Save Selected Features and Tuned Hyperparameters

# %%
# save dataframes as csv files
paras.to_csv('data/paras',header = True, index = True)
feats.to_csv('data/feats',header = True, index = True)
